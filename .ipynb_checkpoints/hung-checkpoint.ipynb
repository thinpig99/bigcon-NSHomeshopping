# %% [markdown]
# # 제가 표시하는 부분까지는 그냥 우리 예측모델 변수 만들고 학습시키는 부분입니다.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import requests
from bs4 import BeautifulSoup
from pprint import pprint
import time
import re
import time
import datetime
import math

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

pd.set_option('display.max_columns', None)

# %%
train = pd.read_csv(r'./train_new.csv')
test = pd.read_csv(r'./test_new.csv')

# %%
# train셋의 취급액 이름이 달라서 통일시켜줍니다. 우리의 소원은 통일.
train = train.rename(columns = {' 취급액 ':'취급액'})
# 전처리를 한 번에 해주기 위해서 train, test를 합쳐줍니다.
df_all = pd.concat([train, test]).reset_index()

# %%
def make_cast_time(train): # nan값이 있는 초기 데이터셋을 써야 하기 때문에 가장 먼저 돌려줍니다. 자세한 알고리즘은 창고에서 찾아보세요.

    # 일단 nan값을 노출칼럼에만 남기기 위해서 나머지 nan값 전처리 미리 해버리겠습니다.
    train['취급액'] = train['취급액'].fillna('0')
    train = train[train.상품군 != '무형']

    # nan값 있는 애들을 따로 저장해둡니다.
    train_yes_nan = train[train['노출(분)'].isnull()]
    # nan값 없는 애들을 따로 저장해줍니다. 이놈들로 작업할겁니다.
    train_not_nan = train.dropna()

    # 인덱스 꼬여서 포문 안 돌아가기 때문에 인덱스 리셋하고 나중에 불러와주기 위해서 따로 저장해줍니다.
    train_not_nan_index = train_not_nan.index
    # 리셋 인덱스 해줍니다.
    train_not_nan_reset_index = train_not_nan.reset_index(drop=True)

    # 여기서부터 cast_time, cast_count 포문-----------------------------------------------------
    cast_time = []
    cast_count = []
    time = 0.
    count = 1

    for i in range(len(train_not_nan_reset_index)):
        if i == 0: # 첫번째 행은 이걸로 하십쇼.
            time = train_not_nan_reset_index['노출(분)'][i] # 더하지 않고, 자기 노출을 그대로 가져옵니다.
            count = 1 # count도 1로 초기화 합니다.
            cast_time.append(time) # 그리고 어펜드.
            cast_count.append(count) # 그리고 어펜드.
        elif train_not_nan_reset_index['상품코드'][i] == train_not_nan_reset_index['상품코드'][i-1]: # 자기의 상품코드가 앞행의 상품코드와 같을 때
            time += train_not_nan_reset_index['노출(분)'][i] # 기존 누적된 노출에 자기 노출을 더한다.
            count += 1 # count도 1을 더해줍니다.
            cast_time.append(time) # 그리고 어펜드.
            cast_count.append(count) # 그리고 어펜드.
        else: # 근데 자기 상품코드와 앞행의 상품코드가 다르다면, 새로운 방송이 시작된 거겠죠?
            time = train_not_nan_reset_index['노출(분)'][i] # 더하지 않고, 자기 노출을 그대로 가져옵니다.
            count = 1 # count도 1로 초기화 합니다.
            cast_time.append(time) # 그리고 어펜드.
            cast_count.append(count) # 그리고 어펜드.
    # 포문 끝------------------------------------------------------------  
    # 컬럼으로 박아줍니다.
    train_not_nan_reset_index['cast_time'] = cast_time
    train_not_nan_reset_index['cast_count'] = cast_count
    
    # 여기서부터 cast_time_sum, cast_count_sum 포문-------------------------------------------------
    cast_time_sum = []
    cast_count_sum = []

    for i in range(len(train_not_nan_reset_index)):
        if i == max(train_not_nan_reset_index.index): #마지막은 비교할 다음타자가 없으니 바로 넣기.
            cast_time_sum.append(train_not_nan_reset_index['cast_time'][i])
            cast_count_sum.append(train_not_nan_reset_index['cast_count'][i])
        elif train_not_nan_reset_index['상품코드'][i] == train_not_nan_reset_index['상품코드'][i+1]: # 자기와 다음타자의 상품코드가 같으면
            cast_time_sum.append(np.nan)
            cast_count_sum.append(np.nan)
        else: # 자기와 다음타자의 상품코드가 다르면
            cast_time_sum.append(train_not_nan_reset_index['cast_time'][i])
            cast_count_sum.append(train_not_nan_reset_index['cast_count'][i])
            
    # 포문 끝----------------------------------------------------------------------
    # 칼럼으로 박아줍니다.
    train_not_nan_reset_index['cast_time_sum'] = cast_time_sum
    train_not_nan_reset_index['cast_count_sum'] = cast_count_sum
    # 백필로 nan값 채워줍니다.
    train_not_nan_reset_index.fillna(method='bfill', inplace=True)
    

    # 원래 인덱스 다시 넣어줍니다.
    train_not_nan_reset_index.index = train_not_nan_index
    # 컨캣으로 밑으로 붙여주고,
    train_concat = pd.concat([train_not_nan_reset_index, train_yes_nan], axis=0)
    # 소트 인덱스 먼저 하고,
    train_concat_sort_index = train_concat.sort_index()
    # ffill 로 채워줍니다. 끝. 이거 너무 힘들었다 진짜 레알.
    train = train_concat_sort_index.fillna(method='ffill')
    
    # 누적 방송 시간 비율 칼럼을 만들어줍니다.
    train['cast_time_ratio'] = train.cast_time / train.cast_time_sum
    
    # 인덱스 리셋해줍니다.
    train = train.reset_index(drop=True)
    
    # 다이어트
    train['cast_count'] = train.cast_count.astype(np.int16)
    
    return train

df_all = make_cast_time(df_all)
df_all.shape
# Out:
# (40088, 14)

# %%
# 기본 전처리 함수
def preprocessing_1(df):
    
    # 취급액과 판매단가 수치형 변수로 바꾸기.
    df['취급액'] = df['취급액'].apply(lambda x: x.replace(',', ''))
    df['판매단가'] = df['판매단가'].apply(lambda x: x.replace(',', ''))
    df['취급액'] = df['취급액'].astype(np.int32)
    df['판매단가'] = df['판매단가'].astype(np.int32)
    
    # 칼럼명 너무 어려우니까 쪼금만 바꿔줍니다.
    #df = df.rename(columns = {' 취급액 ':'취급액'})
    
    return df

df_all = preprocessing_1(df_all)
df_all.shape
# Out:
# (40088, 14)

# %%
# 상품명 전처리 함수
def preprocessing_3(train):
    # 1. 일시불/무이자/없음
    train.loc[train['상품명'].str.contains('일시불') == True, "상품명_plan"] = '1'
    train.loc[train['상품명'].str.contains('일\)') == True, "상품명_plan"] = '1'
    train.loc[train['상품명'].str.contains('무이자') == True, "상품명_plan"] = '2'
    train.loc[train['상품명'].str.contains('무\)') == True, "상품명_plan"] = '2'
    train['상품명_plan'] = train['상품명_plan'].fillna('0')

    # 2. 추가구성/단품구성
    train.loc[train['상품명'].str.contains('\+') == True, "상품명_add"] = '1'
    train['상품명_add'] = train['상품명_add'].fillna('0')

    # 3. 기타/삼성/LG
    train.loc[train['상품명'].str.contains('삼성') == True, "상품명_maker"] = '1'
    train.loc[train['상품명'].str.contains('LG') == True, "상품명_maker"] = '2'
    train['상품명_maker'] = train['상품명_maker'].fillna('0')

    # 4. 세트구성/단품구성
    train.loc[train['상품명'].str.contains('세트') == True, "상품명_set"] = '1'
    train['상품명_set'] = train['상품명_set'].fillna('0')

    # 5. 여성/남성/없음
    train.loc[train['상품명'].str.contains('여성') == True, "상품명_sex"] = '1'
    train.loc[train['상품명'].str.contains('브라') == True, "상품명_sex"] = '1'
    train.loc[train['상품명'].str.contains('란쥬') == True, "상품명_sex"] = '1'
    train.loc[train['상품명'].str.contains('블라우스') == True, "상품명_sex"] = '1'
    train.loc[train['상품명'].str.contains('밍크') == True, "상품명_sex"] = '1'
    train.loc[train['상품명'].str.contains('남성') == True, "상품명_sex"] = '2'
    train.loc[train['상품명'].str.contains('드로즈') == True, "상품명_sex"] = '2'
    train.loc[train['상품명'].str.contains('트렁크') == True, "상품명_sex"] = '2'
    train['상품명_sex'] = train['상품명_sex'].fillna('0')

    # category로 형변환해서 다이어트 시켜줍니다.
    train['상품명_plan'] = train['상품명_plan'].astype('category')
    train['상품명_add'] = train['상품명_add'].astype('category')
    train['상품명_maker'] = train['상품명_maker'].astype('category')
    train['상품명_set'] = train['상품명_set'].astype('category')
    train['상품명_sex'] = train['상품명_sex'].astype('category')
    
    return train

df_all = preprocessing_3(df_all)
df_all.shape
# Out:
# (40088, 19)

# %%
def make_fake_weight(train):
    fake_weight = []
    weight = 1

    for i in range(len(train)):
        if i == 0: # 첫번째 행은 이걸로 하십쇼.
            weight = 1 # count도 1로 초기화 합니다.
            fake_weight.append(weight) # 그리고 어펜드.
            
        elif train['마더코드'][i] == train['마더코드'][i-1]: # 자기의 마더코드가 앞행의 것과 같을 때
            if train['판매단가'][i] < train['판매단가'][i-1]: # 자기의 단가가 앞행의 것보다 작으면(같으면 안됨)
                weight +=1 # 가중치 1을 더하고,
                fake_weight.append(weight) # 그리고 어펜드
            else: # 자기의 단가가 앞행의 것과 같거나 더 크면(더 클 수는 없음.)
                weight = 1 # 가중치 1로 초기화
                fake_weight.append(weight)
                
        else: # 근데 자기 마더코드와 앞행의 마더코드가 다르다면, 새로운 방송이 시작된 거겠죠?
            weight = 1 # 가중치 1로 초기화
            fake_weight.append(weight)
            
    train['fake_weight'] = fake_weight
    train['fake_weight'] = train.fake_weight.apply(lambda x: -(x*x))
    
    return train

df_all = make_fake_weight(df_all)
df_all.shape
# Out:
# (40088, 20)

# %%
def make_train_fake(train):
    
    # 더 정확한 변수 생성을 위해 기계가 걸러내지 못하는 조건을 쳐내줍니다.
    train_fake = train[train.상품명_plan == '0'] # 할부플랜이 다른 애들 쳐내기
    train_fake = train_fake[train_fake.상품명_sex == '0'] # 성별이 다른 애들 쳐내기.
    
    # 포문 돌리기 위해 인덱스 리셋 해줍니다.
    train_fake.reset_index(drop=True, inplace=True)

    return train_fake

# %%
def make_fake_weight2(train):
    fake_weight = []
    weight = 0

    for i in range(len(train)):
        if i == 0: # 첫번째 행은 이걸로 하십쇼.
            weight = 0 # count도 1로 초기화 합니다.
            fake_weight.append(weight) # 그리고 어펜드.
            
        elif train['마더코드'][i] == train['마더코드'][i-1]: # 자기의 마더코드가 앞행의 것과 같을 때
            if train['판매단가'][i] == train['판매단가'][i-1]: # 자기의 단가가 앞행의 것과 같을 때
                if train['방송일시'][i] == train['방송일시'][i-1]:
                    if train['상품코드'][i] != train['상품코드'][i-1]: # 상품코드는 일치하지 않으면 조건 성립
                        weight -=1 # 가중치 1을 빼고,
                        fake_weight.append(weight) # 그리고 어펜드
                    else: # 상품코드까지 같으면 동일 상품.
                        weight = 0
                        fake_weight.append(weight)
                else: #방송일시가 다르면 새로운 방송 시작
                    weight = 0 # 가중치 0로 초기화
                    fake_weight.append(weight)
            else: # 판매단가가 다르면 다른 상품
                weight = 0 # 가중치 0로 초기화
                fake_weight.append(weight)
        else: # 근데 자기 마더코드와 앞행의 마더코드가 다르다면, 새로운 방송이 시작된 거겠죠?
            weight = 0 # 가중치 1로 초기화
            fake_weight.append(weight)
            
    train['fake_weight2'] = fake_weight
    
    return train

# %%
df_fake = make_train_fake(df_all)
df_fake = make_fake_weight2(df_fake)
df_all.shape

# 기존 데이터에 합쳐줍니다.
df_all = pd.merge(df_all, df_fake[['방송일시','마더코드','상품코드','상품명','판매단가', 'fake_weight2']],
                 on=['방송일시','마더코드','상품코드','상품명','판매단가'], how='left')

# 빈 값은 전부 0으로 채워줍니다.
df_all['fake_weight2'] = df_all['fake_weight2'].fillna(0)

# %%
category_train = pd.read_csv('/gdrive/My Drive/categorized_train_0908.csv') # 카테고리 추가되었습니다.
category_test = pd.read_csv('/gdrive/My Drive/categorized_test_0908.csv') # 카테고리 추가되었습니다.

# 전처리를 한 번에 해주기 위해서 train, test를 합쳐줍니다.
category = pd.concat([category_train, category_test]).reset_index()

# 난 값 먼저 채워 줍니다.
category['cat3'] = category.apply(lambda x: x['cat2'] if x['cat3'] != x['cat3'] else x['cat3'], axis=1)

def preprocessing_to_merge(df):
    # merge를 위해 datetime으로 바꿔줍니다..
    df['방송일시'] = pd.to_datetime(df['방송일시'], errors='coerce')
    df['방송일시'] = df['방송일시'].astype(str)
    
    # key 칼럼을 만들어줍니다. 방송일시만으로는 안되니, 방송일시+상품명을 해줍니다.
    df['key'] = df['방송일시'] + df['상품명']
    
    return df

def preprocessing_merging(df1, df2):
    # df1이 왼쪽, df2가 오른쪽입니다.
    df3 = pd.merge(df1, df2[['key','cat1','cat2','cat3']], how='left', on=['key'])
    df3 = df3.drop('key', axis=1) # key 칼럼은 드랍.
    
    return df3
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-90311d1a3b51> in <module>
# ----> 1 category_train = pd.read_csv('/gdrive/My Drive/categorized_train_0908.csv') # 카테고리 추가되었습니다.
#       2 category_test = pd.read_csv('/gdrive/My Drive/categorized_test_0908.csv') # 카테고리 추가되었습니다.
#       3
#       4 # 전처리를 한 번에 해주기 위해서 train, test를 합쳐줍니다.
#       5 category = pd.concat([category_train, category_test]).reset_index()
#
# ~\anaconda3\envs\Wyatt37\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\envs\Wyatt37\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\envs\Wyatt37\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\envs\Wyatt37\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\envs\Wyatt37\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File /gdrive/My Drive/categorized_train_0908.csv does not exist: '/gdrive/My Drive/categorized_train_0908.csv'

# %%
df_all = preprocessing_to_merge(df_all)
#category = preprocessing_to_merge(category)
category1 = preprocessing_to_merge(category)
df_all = preprocessing_merging(df_all, category1)
df_all.shape

# %%
# 방송일시 쪼개기 전처리 함수
def preprocessing_4(train):
    # datetime으로 바꿔줍니다.
    train['방송일시'] = pd.to_datetime(train['방송일시'], errors='coerce')
   
    # 월일이 다음날로 넘어가는 것을 막기 위해서 3시간씩 앞으로 땡겨줍니다. 마지막에 다시 더해줘야 합니다.
    delta = datetime.timedelta(hours=3)
    train['방송일시'] = train.방송일시.apply(lambda x: x - delta)

    # dayofweek는 날짜에서 요일(월~일)을 가져오는 기능입니다.
    # 값은 0(월), 1(화), 2(수), 3(목), 4(금), 5(토), 6(일) 을 나타냅니다.
    train["방송일시_dow"] = train["방송일시"].dt.dayofweek

    # 요일 외에 다른 정보를 가져오기 위해서 다시 string으로 바꿔줍니다.
    train['방송일시'] = train.방송일시.astype(str)

    # MMDDhhmm 정보를 가져옵니다.
    train['방송일시_MM'] = train['방송일시'].apply(lambda x: x[5:7])
    train['방송일시_DD'] = train['방송일시'].apply(lambda x: x[8:10])
    train['방송일시_hh'] = train['방송일시'].apply(lambda x: x[11:13])
    train['방송일시_mm'] = train['방송일시'].apply(lambda x: x[14:16])

    # schedule 관련 칼럼을 더 만들어보겠습니다. # MMDD # DDHH # HHMM # weekday/weekends
    train['방송일시_MMDD'] = train['방송일시_MM'] + train['방송일시_DD']
    train['방송일시_DDhh'] = train['방송일시_DD'] + train['방송일시_hh']
    train['방송일시_hhmm'] = train['방송일시_hh'] + train['방송일시_mm']
    train['방송일시_MMDDhh'] = train['방송일시_MM'] + train['방송일시_DD'] + train['방송일시_hh']

    # mmmm_1 은 1일 사이클로 분단위로 환산한 것
    # mmmm_2 는 1달 사이클로 분단위로 환산한 것
    # mmmm_3 는 1년 사이클로 분단위로 환산한 것
    train['방송일시_mmmm_1'] = train['방송일시_hh'].astype(int) * train['방송일시_mm'].astype(int) * 60
    train['방송일시_mmmm_2'] = train['방송일시_DD'].astype(int) * train['방송일시_hh'].astype(int) * train['방송일시_mm'].astype(int) * 60
    train['방송일시_mmmm_3'] = train['방송일시_MM'].astype(int) * train['방송일시_DD'].astype(int) * train['방송일시_hh'].astype(int) * train['방송일시_mm'].astype(int) * 60

    # weekday = 1 / weekends = 0
    train.loc[train.방송일시_dow == 5, '방송일시_dow2'] = '0'
    train.loc[train.방송일시_dow == 6, '방송일시_dow2'] = '0'
    train['방송일시_dow2'] = train.방송일시_dow2.fillna('1')
    
    #다이어트
    train['방송일시_dow'] = train.방송일시_dow.astype(np.int16)
    train['방송일시_MM'] = train.방송일시_MM.astype('category')
    train['방송일시_DD'] = train.방송일시_DD.astype('category')
    train['방송일시_hh'] = train.방송일시_hh.astype('category')
    train['방송일시_mm'] = train.방송일시_mm.astype('category')
    train['방송일시_MMDD'] = train.방송일시_MMDD.astype('category')
    train['방송일시_DDhh'] = train.방송일시_DDhh.astype('category')
    train['방송일시_hhmm'] = train.방송일시_hhmm.astype('category')
    train['방송일시_dow2'] = train.방송일시_dow2.astype('category')
    
    return train

df_all = preprocessing_4(df_all)
df_all.shape

# %%
def pre_nlp(train):
    # 제품명에서 불필요한 요소 전처리
    new_product_name = []

    re_stop = re.compile("""\([가-힣]{1,5}\+[가-힣]{1,5}\)|\(?무이자\)?\s?|\(?일시불\)?\s?|\(?초특가\)?\s?|\(?무\)\s?|\(?유\)\s?|\(?일\)\s?|무료체험|
    |포함|국내[가-힣]+\s|무료설치|\s?신제품\s?|\s?패키지\s?|[0-9]+종|풀코디|set|SET|풀세트|[0-9]+세트|더블팩|싱글팩|[0-9]{1,2}\+[0-9]{1,2}|[0-9]{1,2}인용|[0-9]{1,2}박스|[0-9\.]{1,4}미터|[0-9\.]{1,4}kg|[0-9\.]{1,4}[kKgG]|[0-9]{1,3}[벌롤종단구대P개통병포미봉팩장gL매]|
    |\s[0-9\.]{1,4}[Mm]|\(.{1,10}\)$|^\(.?\)|^[0-9]{2,4}\s|\s+[0-9]{2,4}\s|[0-9]{2,4}년\s|[0-9]{2,4}년형\s|시즌[0-9]|[0-9]{1,3}\%|\(.{1,20}\)$|기본형|고급형|오리지널|[대중소大中小]형|.{1,10}by|,|\s?총[0-9\s]|^[가-힣a-zA-Z]{3,3}의|
    |S\/S|F\/W|f\/w|s\/s|[가-힣]+형\s|[슈퍼]{0,2}싱글|\s[SQK퀸킹]{1,2}\s|[SQK퀸킹]{1,2}$|[가-힣]{0,2}사이즈""")

    remnants = re.compile('[",g\+lL-]\s|ml|_|\sx|[\[\]\］!"#$%&\'()*+,./:;<=>?@\^_`{|}~-]|\s종$|\s[0-9]+\s|\s{2,}')

    for i in train.상품명:
        tmp = re_stop.sub(' ',i)
        tmp = tmp.strip()
        tmp = remnants.sub(' ',tmp)
        new_product_name.append(tmp.strip())
    
    train['new_상품명'] = new_product_name
    
    # 상품명에서 브랜드 추출
    train['상품명_brand'] = train['new_상품명'].apply(lambda x: x[:2])
    
    return train

df_all = pre_nlp(df_all)
df_all.shape

# %%
naver_train = pd.read_csv('/gdrive/My Drive/naver_train.csv')
naver_test = pd.read_csv('/gdrive/My Drive/naver_test.csv')

# train용, test용 합쳐줍니다.
naver = pd.concat([naver_train, naver_test]).reset_index(drop=True)

# 중복 값들이 있습니다. 제거해줍니다.
naver = naver.drop_duplicates(subset=['상품명'])

# %%
def outside_feature_naver(train, naver):
    # 네이버 크롤링 데이터를 합친 후 전처리 하는 코드입니다.
    # 먼저 합쳐줍니다.
    train = pd.merge(train, naver, on='상품명', how='left')
    
    # 전처리 해줍니다.
    train['review_counts'] = train['review_counts'].apply(lambda x: x.replace(',',''))
    train['internet_price'] = train['internet_price'].apply(lambda x: x.replace(',',''))
    train['internet_price'] = train['internet_price'].apply(lambda x: x.replace('원',''))
    train['review_counts'] = train['review_counts'].astype(int)
    train['internet_price'] = train['internet_price'].astype(int)

    # 오차를 컬럼으로 만들어줍니다.
    train['price_minus'] = train['판매단가'] - train['internet_price']

    # 네이버에 서칭이 되는지 여부를 알려줍니다.
    train['search_naver'] = train['internet_price'] + train['review_counts']
    train['search_naver'] = train['search_naver'].apply(lambda x: 0 if x == 0 else 1)
    
    return train

df_all = outside_feature_naver(df_all, naver)
df_all.shape

# %%
# 기상청 통계 파일 읽기
weather_train = pd.read_csv('/gdrive/My Drive/weather_train.csv', encoding='latin1')
weather_test = pd.read_csv('/gdrive/My Drive/weather_test.csv', encoding='latin1')
weather = pd.concat([weather_train, weather_test], ignore_index=True)
columns = ['location_id','location','date','temperature']
weather.columns = columns

def outside_feature_weather(weather):
    # 날씨 변수를 합쳐주기 위한 전처리 작업니다.
    # datetime으로 바꿔줍니다.
    weather['date'] = pd.to_datetime(weather['date'], errors='coerce')

    # 월일이 다음날로 넘어가는 것을 막기 위해서 3시간씩 앞으로 땡겨줍니다. 마지막에 다시 더해줘야 합니다.
    delta = datetime.timedelta(hours=3)
    weather['date'] = weather.date.apply(lambda x: x - delta)

    # 요일 외에 다른 정보를 가져오기 위해서 다시 string으로 바꿔줍니다.
    weather['date'] = weather.date.astype(str)
    
    # key column 만들어주기.
    weather['weather_key'] = (
        weather['date'].apply(lambda x: x[2:4]) + 
        weather['date'].apply(lambda x: x[5:7]) + 
        weather['date'].apply(lambda x: x[8:10]) + 
        weather['date'].apply(lambda x: x[11:13])
    )

    # 필요없는 칼럼은 미리 버려줍니다.
    weather.drop(['location_id', 'location', 'date'], axis=1, inplace=True)
    
    return weather

# %%
weather = outside_feature_weather(weather)
# key column 만들어주기.
df_all['weather_key'] = (
    df_all['방송일시'].apply(lambda x: x[2:4]) + 
    df_all['방송일시'].apply(lambda x: x[5:7]) + 
    df_all['방송일시'].apply(lambda x: x[8:10]) + 
    df_all['방송일시'].apply(lambda x: x[11:13])
)
# 합쳐줍니다.
df_all = pd.merge(df_all, weather, on='weather_key', how='left')
# 관측이 안 된 날이 하루가 있더군요.
df_all['temperature'] = df_all['temperature'].fillna(method='ffill')
# key column 지워줍니다.
df_all.drop(['weather_key'], axis=1, inplace=True)
df_all.shape

# %%
# 라벨인코딩 숫자가 많아지니 함수로 만들어버립니다.
def label_encoding(train_, columns, number):
    length = range(number)
    for c, i in zip(columns, length):
        # 라벨인코더 피팅
        globals()['encoder_{}:'.format(i)] = LabelEncoder()
        globals()['encoder_{}:'.format(i)].fit(train_[c].values)
        
        # 트레인셋에 트랜스폼
        train_['encoding_{}:'.format(c)] = globals()['encoder_{}:'.format(i)].transform(train_[c])

# 인코딩할 컬럼을 리스트로 넣어줍니다.
columns = ['상품명', '상품군', 'cat1', 'cat2', 'cat3', '상품명_brand', 'new_상품명']
number = len(columns)

# 함수로 바로 처리.
label_encoding(df_all, columns, number)

# %%
df_all.drop(['index'], axis=1, inplace=True)
train = df_all[:37372]
test = df_all[37372:]

# 예측 값 추정이 불가능한 취급액 0원인 애들 제거해줍니다.

train = train[train.취급액 != 0]
train.shape

# train 셋의 아웃라이어를 제거해봅니다...1억 이상의 취급액을 가진 데이터가 약 1% 정도 있습니다.

train = train[train.취급액 < 100000000]
train.shape
# Out:
# (35196, 50)

# %%
features = ['노출(분)', '마더코드', '상품코드', '판매단가',
       'cast_time', 'cast_count', 'cast_time_sum', 'cast_count_sum',
       'cast_time_ratio', '상품명_plan', '상품명_add', '상품명_maker', '상품명_set',
       '상품명_sex', 'fake_weight', 'fake_weight2',
       '방송일시_dow', '방송일시_MM', '방송일시_DD', '방송일시_hh', '방송일시_mm', '방송일시_MMDD',
       '방송일시_DDhh', '방송일시_hhmm', '방송일시_MMDDhh', '방송일시_mmmm_1', '방송일시_mmmm_2',
       '방송일시_mmmm_3', '방송일시_dow2', 'review_counts',
       'price_minus', 'search_naver', 'temperature',
       'encoding_상품명:', 'encoding_상품군:', 'encoding_cat1:', 'encoding_cat2:',
       'encoding_cat3:', 'encoding_상품명_brand:', 'encoding_new_상품명:'
           ]

label = '취급액'

# %%
# rating_mean 은 일단 제외하고 학습합니다.
# 변수 순서가 바뀌면 점수가 바뀝니다.

X_train = train[features].values 
y_train = train[label].values
X_test = test[features].values 
y_test = test[label].values

# %%
y_train_log = np.log(y_train)

# %%
rf = RandomForestRegressor(n_jobs=3,
                           random_state=592)

rf.fit(X_train, y_train_log)
pred_log = rf.predict(X_test)

# %%
pred_log_T = np.exp(1)**pred_log

# %%
def mape(y_true, y_pred):
    assert len(y_true) == len(y_pred)
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mape(y_test, pred_log_T)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
# inf

# %% [markdown]
# # 여기부터 헝가리안을 위한 작업입니다

# %%
submission = pd.read_csv('/gdrive/My Drive/test_new.csv')
submission = submission[submission.상품군 != '무형']

submission = submission.iloc[:64]

# %%
# index(같은 방송이면 같은 숫자가 오도록 묶어주는 지표)를 생성합니ㅏㄷ.
submission = make_cast_time(submission)
submission['index'] = 1
for i in range(1, len(submission)):
  if (submission['cast_count'][i] == 1) & (submission['방송일시'][i] != submission['방송일시'][i-1]):
    submission['index'][i] = submission['index'][i-1] +1
  else:
    submission['index'][i] = submission['index'][i-1]
print(submission.shape)

# index 별로 최대 방송시간 즉, 몇회 방송을 했는지를 time이란 이름으로 구합니다.
tmp = submission.groupby('index').max()[['cast_count']].reset_index()
tmp.rename({'cast_count':'time'}, axis=1, inplace= True)
submission = pd.merge(submission, tmp, on='index', how='left')
submission
# Out:
# (64, 14)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                 방송일시  노출(분)    마더코드    상품코드                        상품명   상품군  \
# 0    2020-06-01 6:20   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 1    2020-06-01 6:40   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 2    2020-06-01 7:00   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 3    2020-06-01 7:20   20.0  100445  202278       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    속옷
# 4    2020-06-01 7:40   20.0  100445  202278       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    속옷
# ..               ...    ...     ...     ...                        ...   ...
# 59  2020-06-01 23:00   20.0  100205  200730  보루네오 델루나 유로탑 슬라이딩 LED침대 킹    가구
# 60  2020-06-01 23:20   20.0  100320  201016            올바로 문어발 샤워기 1+1  생활용품
# 61  2020-06-01 23:20   20.0  100320  201017            올바로 문어발 샤워기 1세트  생활용품
# 62  2020-06-01 23:40   20.0  100320  201016            올바로 문어발 샤워기 1+1  생활용품
# 63  2020-06-01 23:40   20.0  100320  201017            올바로 문어발 샤워기 1세트  생활용품
#
#          판매단가 취급액  cast_time  cast_count  cast_time_sum  cast_count_sum  \
# 0     59,800    0       20.0           1           60.0             3.0
# 1     59,800    0       40.0           2           60.0             3.0
# 2     59,800    0       60.0           3           60.0             3.0
# 3     69,900    0       20.0           1           60.0             3.0
# 4     69,900    0       40.0           2           60.0             3.0
# ..        ...  ..        ...         ...            ...             ...
# 59   648,000    0       60.0           3           60.0             3.0
# 60    54,900    0       20.0           1           40.0             2.0
# 61    28,900    0       20.0           1           40.0             2.0
# 62    54,900    0       40.0           2           40.0             2.0
# 63    28,900    0       40.0           2           40.0             2.0
#
#     cast_time_ratio  index  time
# 0          0.333333      1     3
# 1          0.666667      1     3
# 2          1.000000      1     3
# 3          0.333333      2     3
# 4          0.666667      2     3
# ..              ...    ...   ...
# 59         1.000000     15     3
# 60         0.500000     16     2
# 61         0.500000     16     2
# 62         1.000000     16     2
# 63         1.000000     16     2
#
# [64 rows x 15 columns]

# %%
# 3회방송하는 모든 방송의 인덱스를 모아준 후 해당 방송의 시간을 time_li에 넣어둡니다.
ind = np.sort(submission[submission['time'] == 3]['index'].unique())
time_li = []
for i in ind:
  time_li.append(np.sort(submission[submission['index'] == i]['방송일시'].unique()).tolist())
time_li
# Out:
# [['2020-06-01 6:20', '2020-06-01 6:40', '2020-06-01 7:00'],
#  ['2020-06-01 7:20', '2020-06-01 7:40', '2020-06-01 8:00'],
#  ['2020-06-01 8:20', '2020-06-01 8:40', '2020-06-01 9:00'],
#  ['2020-06-01 10:00', '2020-06-01 9:20', '2020-06-01 9:40'],
#  ['2020-06-01 10:20', '2020-06-01 10:40', '2020-06-01 11:00'],
#  ['2020-06-01 11:20', '2020-06-01 11:40', '2020-06-01 12:00'],
#  ['2020-06-01 12:20', '2020-06-01 12:40', '2020-06-01 13:00'],
#  ['2020-06-01 15:20', '2020-06-01 15:40', '2020-06-01 16:00'],
#  ['2020-06-01 16:20', '2020-06-01 16:40', '2020-06-01 17:00'],
#  ['2020-06-01 17:20', '2020-06-01 17:40', '2020-06-01 18:00'],
#  ['2020-06-01 18:20', '2020-06-01 18:40', '2020-06-01 19:00'],
#  ['2020-06-01 19:20', '2020-06-01 19:40', '2020-06-01 20:00'],
#  ['2020-06-01 20:20', '2020-06-01 20:40', '2020-06-01 21:00'],
#  ['2020-06-01 21:20', '2020-06-01 21:40', '2020-06-01 22:00'],
#  ['2020-06-01 22:20', '2020-06-01 22:40', '2020-06-01 23:00']]

# %%
# new1 데이터안에는 모든 3회짜리 방송 시간의 첫 시간이 들어가게 됩니다.
new1 = pd.DataFrame()
for i in range(len(submission[submission['time'] == 3]['index'].unique())):
  tmp = submission[submission['time'] == 3].copy()
  tmp['방송일시'] = tmp['cast_count'].apply(lambda x: time_li[i][x-1])
  new1 = new1.append(tmp)
  new1.reset_index(drop=True, inplace=True)

# %%
ind = np.sort(submission[submission['time'] == 2]['index'].unique())
time_li = []
for i in ind:
  time_li.append(np.sort(submission[submission['index'] == i]['방송일시'].unique()).tolist())
time_li

# new2는 같은 작업을 2회짜리 방송을 위해 만든겁니다
new2 = pd.DataFrame()
for i in range(len(submission[submission['time'] == 2]['index'].unique())):
  tmp = submission[submission['time'] == 2].copy()
  tmp['방송일시'] = tmp['cast_count'].apply(lambda x: time_li[i][x-1])
  new2 = new2.append(tmp)
  new2.reset_index(drop=True, inplace=True)

all_time = new1.append(new2)
all_time.reset_index(inplace=True, drop=True)
all_time
# Out:
#                  방송일시  노출(분)    마더코드    상품코드                        상품명   상품군  \
# 0     2020-06-01 6:20   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 1     2020-06-01 6:40   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 2     2020-06-01 7:00   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 3     2020-06-01 6:20   20.0  100445  202278       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    속옷
# 4     2020-06-01 6:40   20.0  100445  202278       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    속옷
# ..                ...    ...     ...     ...                        ...   ...
# 899  2020-06-01 23:00   20.0  100205  200730  보루네오 델루나 유로탑 슬라이딩 LED침대 킹    가구
# 900  2020-06-01 23:20   20.0  100320  201016            올바로 문어발 샤워기 1+1  생활용품
# 901  2020-06-01 23:20   20.0  100320  201017            올바로 문어발 샤워기 1세트  생활용품
# 902  2020-06-01 23:40   20.0  100320  201016            올바로 문어발 샤워기 1+1  생활용품
# 903  2020-06-01 23:40   20.0  100320  201017            올바로 문어발 샤워기 1세트  생활용품
#
#           판매단가 취급액  cast_time  cast_count  cast_time_sum  cast_count_sum  \
# 0      59,800    0       20.0           1           60.0             3.0
# 1      59,800    0       40.0           2           60.0             3.0
# 2      59,800    0       60.0           3           60.0             3.0
# 3      69,900    0       20.0           1           60.0             3.0
# 4      69,900    0       40.0           2           60.0             3.0
# ..         ...  ..        ...         ...            ...             ...
# 899   648,000    0       60.0           3           60.0             3.0
# 900    54,900    0       20.0           1           40.0             2.0
# 901    28,900    0       20.0           1           40.0             2.0
# 902    54,900    0       40.0           2           40.0             2.0
# 903    28,900    0       40.0           2           40.0             2.0
#
#      cast_time_ratio  index  time
# 0           0.333333      1     3
# 1           0.666667      1     3
# 2           1.000000      1     3
# 3           0.333333      2     3
# 4           0.666667      2     3
# ..               ...    ...   ...
# 899         1.000000     15     3
# 900         0.500000     16     2
# 901         0.500000     16     2
# 902         1.000000     16     2
# 903         1.000000     16     2
#
# [904 rows x 15 columns]

# %%
def make_features(df_all):
  df_all = preprocessing_1(df_all)
  df_all = preprocessing_3(df_all)
  df_all = make_fake_weight(df_all)
  df_fake = make_train_fake(df_all)
  df_fake = make_fake_weight2(df_fake)
  df_all = pd.merge(df_all, df_fake[['방송일시','마더코드','상품코드','상품명','판매단가', 'fake_weight2']],
                  on=['방송일시','마더코드','상품코드','상품명','판매단가'], how='left')
  df_all['fake_weight2'] = df_all['fake_weight2'].fillna(0)
  df_all = preprocessing_to_merge(df_all)
  global category
  category = preprocessing_to_merge(category)
  df_all = preprocessing_merging(df_all, category)
  df_all = preprocessing_4(df_all)
  df_all = pre_nlp(df_all)
  global naver
  df_all = outside_feature_naver(df_all, naver)
  global weather
  # key column 만들어주기.
  df_all['weather_key'] = (
      df_all['방송일시'].apply(lambda x: x[2:4]) + 
      df_all['방송일시'].apply(lambda x: x[5:7]) + 
      df_all['방송일시'].apply(lambda x: x[8:10]) + 
      df_all['방송일시'].apply(lambda x: x[11:13])
  )
  # 합쳐줍니다.
  df_all = pd.merge(df_all, weather, on='weather_key', how='left')
  # 관측이 안 된 날이 하루가 있더군요.
  df_all['temperature'] = df_all['temperature'].fillna(method='ffill')
  # key column 지워줍니다.
  df_all.drop(['weather_key'], axis=1, inplace=True)

  return df_all

# %%
all_time = make_features(all_time)

columns = ['상품명', '상품군', 'cat1', 'cat2', 'cat3', '상품명_brand', 'new_상품명']
number = len(columns)

for i in columns:
  all_time[i] = all_time[i].astype(str)

# 함수로 바로 처리.
label_encoding(all_time, columns, number)
all_time.drop(['index'], axis=1, inplace=True)
# all_time = all_time[all_time.취급액 != 0]

# %%
features = ['노출(분)', '마더코드', '상품코드', '판매단가',
       'cast_time', 'cast_count', 'cast_time_sum', 'cast_count_sum',
       'cast_time_ratio', '상품명_plan', '상품명_add', '상품명_maker', '상품명_set',
       '상품명_sex', 'fake_weight', 'fake_weight2',
       '방송일시_dow', '방송일시_MM', '방송일시_DD', '방송일시_hh', '방송일시_mm', '방송일시_MMDD',
       '방송일시_DDhh', '방송일시_hhmm', '방송일시_MMDDhh', '방송일시_mmmm_1', '방송일시_mmmm_2',
       '방송일시_mmmm_3', '방송일시_dow2', 'review_counts',
       'price_minus', 'search_naver', 'temperature',
       'encoding_상품명:', 'encoding_상품군:', 'encoding_cat1:', 'encoding_cat2:',
       'encoding_cat3:', 'encoding_상품명_brand:', 'encoding_new_상품명:']

vari_pred = all_time[features].values
pred = rf.predict(vari_pred)
pred_exp = np.exp(1)**pred

# %%
all_time['취급액'] = pred_exp
all_time['취급액']
# Out:
# 0      6.665804e+06
# 1      1.576791e+07
# 2      2.238805e+07
# 3      1.126736e+07
# 4      1.531797e+07
#            ...
# 899    3.370175e+07
# 900    2.072989e+07
# 901    1.244619e+06
# 902    2.896003e+07
# 903    5.562182e+06
# Name: 취급액, Length: 904, dtype: float64

# %%
all_time.to_csv('/gdrive/My Drive/all_time.csv', index = False, header = True)

# %%
all_time.pivot_table(index='방송일시', columns='상품명', values='취급액',)
# Out:
# 상품명                  AAC 삼채포기김치 10kg  \
# 방송일시
# 2020-06-01 03:20:00     1.125626e+07
# 2020-06-01 03:40:00     1.979905e+07
# 2020-06-01 04:00:00     2.918797e+07
# 2020-06-01 04:20:00     1.537753e+07
# 2020-06-01 04:40:00     2.261178e+07
# 2020-06-01 05:00:00     2.509282e+07
# 2020-06-01 05:20:00     1.882387e+07
# 2020-06-01 05:40:00     2.170682e+07
# 2020-06-01 06:00:00     2.447198e+07
# 2020-06-01 06:20:00     2.248252e+07
# 2020-06-01 06:40:00     2.456798e+07
# 2020-06-01 07:00:00     1.935477e+07
# 2020-06-01 07:20:00     1.940784e+07
# 2020-06-01 07:40:00     2.223748e+07
# 2020-06-01 08:00:00     2.514516e+07
# 2020-06-01 08:20:00     1.898943e+07
# 2020-06-01 08:40:00     2.474281e+07
# 2020-06-01 09:00:00     2.902499e+07
# 2020-06-01 09:20:00     1.890666e+07
# 2020-06-01 09:40:00     2.210644e+07
# 2020-06-01 10:00:00     2.617263e+07
# 2020-06-01 12:20:00     1.875973e+07
# 2020-06-01 12:40:00     2.270465e+07
# 2020-06-01 13:00:00     2.614047e+07
# 2020-06-01 13:20:00     1.888347e+07
# 2020-06-01 13:40:00     2.290201e+07
# 2020-06-01 14:00:00     2.606753e+07
# 2020-06-01 14:20:00     1.942294e+07
# 2020-06-01 14:40:00     2.315012e+07
# 2020-06-01 15:00:00     2.637520e+07
# 2020-06-01 15:20:00     1.935096e+07
# 2020-06-01 15:40:00     2.344919e+07
# 2020-06-01 16:00:00     2.504560e+07
# 2020-06-01 16:20:00     1.867376e+07
# 2020-06-01 16:40:00     2.264682e+07
# 2020-06-01 17:00:00     2.558281e+07
# 2020-06-01 17:20:00     1.880216e+07
# 2020-06-01 17:40:00     2.296193e+07
# 2020-06-01 18:00:00     2.628877e+07
# 2020-06-01 18:20:00     1.895106e+07
# 2020-06-01 18:40:00     2.312112e+07
# 2020-06-01 19:00:00     2.650674e+07
# 2020-06-01 19:20:00     1.914881e+07
# 2020-06-01 19:40:00     2.223106e+07
# 2020-06-01 20:00:00     2.569203e+07
# 2020-06-01 20:20:00              NaN
# 2020-06-01 20:40:00              NaN
#
# 상품명                  LG 울트라HD TV AI ThinQ(인공지능 씽큐) 55형 55UN7850KNA  \
# 방송일시
# 2020-06-01 03:20:00                                   9.794762e+06
# 2020-06-01 03:40:00                                   9.279898e+06
# 2020-06-01 04:00:00                                   1.265078e+07
# 2020-06-01 04:20:00                                   1.068046e+07
# 2020-06-01 04:40:00                                   9.217256e+06
# 2020-06-01 05:00:00                                   1.240018e+07
# 2020-06-01 05:20:00                                   1.062450e+07
# 2020-06-01 05:40:00                                   9.442327e+06
# 2020-06-01 06:00:00                                   1.252730e+07
# 2020-06-01 06:20:00                                   9.570211e+06
# 2020-06-01 06:40:00                                   1.248244e+07
# 2020-06-01 07:00:00                                   1.092441e+07
# 2020-06-01 07:20:00                                   1.090114e+07
# 2020-06-01 07:40:00                                   9.530545e+06
# 2020-06-01 08:00:00                                   1.208268e+07
# 2020-06-01 08:20:00                                   1.121900e+07
# 2020-06-01 08:40:00                                   9.636247e+06
# 2020-06-01 09:00:00                                   1.208268e+07
# 2020-06-01 09:20:00                                   1.100361e+07
# 2020-06-01 09:40:00                                   9.679618e+06
# 2020-06-01 10:00:00                                   1.208268e+07
# 2020-06-01 12:20:00                                   1.115537e+07
# 2020-06-01 12:40:00                                   9.588984e+06
# 2020-06-01 13:00:00                                   1.294497e+07
# 2020-06-01 13:20:00                                   1.151988e+07
# 2020-06-01 13:40:00                                   9.685820e+06
# 2020-06-01 14:00:00                                   1.294497e+07
# 2020-06-01 14:20:00                                   1.151072e+07
# 2020-06-01 14:40:00                                   9.667422e+06
# 2020-06-01 15:00:00                                   1.294497e+07
# 2020-06-01 15:20:00                                   1.152257e+07
# 2020-06-01 15:40:00                                   9.476953e+06
# 2020-06-01 16:00:00                                   1.367508e+07
# 2020-06-01 16:20:00                                   1.161681e+07
# 2020-06-01 16:40:00                                   9.543361e+06
# 2020-06-01 17:00:00                                   1.392477e+07
# 2020-06-01 17:20:00                                   1.151998e+07
# 2020-06-01 17:40:00                                   9.524364e+06
# 2020-06-01 18:00:00                                   1.390474e+07
# 2020-06-01 18:20:00                                   1.156066e+07
# 2020-06-01 18:40:00                                   1.008708e+07
# 2020-06-01 19:00:00                                   1.461411e+07
# 2020-06-01 19:20:00                                   1.082907e+07
# 2020-06-01 19:40:00                                   9.506034e+06
# 2020-06-01 20:00:00                                   1.402871e+07
# 2020-06-01 20:20:00                                            NaN
# 2020-06-01 20:40:00                                            NaN
#
# 상품명                  LG 울트라HD TV AI ThinQ(인공지능 씽큐) 65형 65UN7850KNA  \
# 방송일시
# 2020-06-01 03:20:00                                   1.312767e+07
# 2020-06-01 03:40:00                                   1.618971e+07
# 2020-06-01 04:00:00                                   2.570144e+07
# 2020-06-01 04:20:00                                   1.360085e+07
# 2020-06-01 04:40:00                                   1.918481e+07
# 2020-06-01 05:00:00                                   2.584506e+07
# 2020-06-01 05:20:00                                   1.343065e+07
# 2020-06-01 05:40:00                                   1.958536e+07
# 2020-06-01 06:00:00                                   2.687485e+07
# 2020-06-01 06:20:00                                   1.998988e+07
# 2020-06-01 06:40:00                                   2.710735e+07
# 2020-06-01 07:00:00                                   1.399615e+07
# 2020-06-01 07:20:00                                   1.405376e+07
# 2020-06-01 07:40:00                                   2.003360e+07
# 2020-06-01 08:00:00                                   2.693046e+07
# 2020-06-01 08:20:00                                   1.405229e+07
# 2020-06-01 08:40:00                                   2.015757e+07
# 2020-06-01 09:00:00                                   2.693046e+07
# 2020-06-01 09:20:00                                   1.402686e+07
# 2020-06-01 09:40:00                                   2.006709e+07
# 2020-06-01 10:00:00                                   2.717493e+07
# 2020-06-01 12:20:00                                   1.453300e+07
# 2020-06-01 12:40:00                                   1.983872e+07
# 2020-06-01 13:00:00                                   2.845860e+07
# 2020-06-01 13:20:00                                   1.454865e+07
# 2020-06-01 13:40:00                                   1.985521e+07
# 2020-06-01 14:00:00                                   2.847064e+07
# 2020-06-01 14:20:00                                   1.443751e+07
# 2020-06-01 14:40:00                                   1.922309e+07
# 2020-06-01 15:00:00                                   2.860824e+07
# 2020-06-01 15:20:00                                   1.477593e+07
# 2020-06-01 15:40:00                                   1.947134e+07
# 2020-06-01 16:00:00                                   2.794641e+07
# 2020-06-01 16:20:00                                   1.462733e+07
# 2020-06-01 16:40:00                                   1.961249e+07
# 2020-06-01 17:00:00                                   2.835662e+07
# 2020-06-01 17:20:00                                   1.463511e+07
# 2020-06-01 17:40:00                                   1.971229e+07
# 2020-06-01 18:00:00                                   2.866000e+07
# 2020-06-01 18:20:00                                   1.437428e+07
# 2020-06-01 18:40:00                                   2.931877e+07
# 2020-06-01 19:00:00                                   3.427985e+07
# 2020-06-01 19:20:00                                   1.371536e+07
# 2020-06-01 19:40:00                                   1.833055e+07
# 2020-06-01 20:00:00                                   2.730496e+07
# 2020-06-01 20:20:00                                            NaN
# 2020-06-01 20:40:00                                            NaN
#
# 상품명                  LG 울트라HD TV AI ThinQ(인공지능 씽큐) 75형 75UN7850KNA  \
# 방송일시
# 2020-06-01 03:20:00                                   1.086922e+07
# 2020-06-01 03:40:00                                   1.653356e+07
# 2020-06-01 04:00:00                                   2.631897e+07
# 2020-06-01 04:20:00                                   1.152596e+07
# 2020-06-01 04:40:00                                   1.965703e+07
# 2020-06-01 05:00:00                                   2.646604e+07
# 2020-06-01 05:20:00                                   1.138676e+07
# 2020-06-01 05:40:00                                   2.020290e+07
# 2020-06-01 06:00:00                                   2.731810e+07
# 2020-06-01 06:20:00                                   2.055536e+07
# 2020-06-01 06:40:00                                   2.759293e+07
# 2020-06-01 07:00:00                                   1.173036e+07
# 2020-06-01 07:20:00                                   1.173036e+07
# 2020-06-01 07:40:00                                   2.067530e+07
# 2020-06-01 08:00:00                                   2.695743e+07
# 2020-06-01 08:20:00                                   1.188887e+07
# 2020-06-01 08:40:00                                   2.085939e+07
# 2020-06-01 09:00:00                                   2.695743e+07
# 2020-06-01 09:20:00                                   1.183372e+07
# 2020-06-01 09:40:00                                   2.065500e+07
# 2020-06-01 10:00:00                                   2.695743e+07
# 2020-06-01 12:20:00                                   1.222621e+07
# 2020-06-01 12:40:00                                   2.072743e+07
# 2020-06-01 13:00:00                                   2.810266e+07
# 2020-06-01 13:20:00                                   1.229895e+07
# 2020-06-01 13:40:00                                   2.079360e+07
# 2020-06-01 14:00:00                                   2.811456e+07
# 2020-06-01 14:20:00                                   1.223137e+07
# 2020-06-01 14:40:00                                   2.013161e+07
# 2020-06-01 15:00:00                                   2.837850e+07
# 2020-06-01 15:20:00                                   1.224720e+07
# 2020-06-01 15:40:00                                   2.034676e+07
# 2020-06-01 16:00:00                                   2.843454e+07
# 2020-06-01 16:20:00                                   1.248361e+07
# 2020-06-01 16:40:00                                   2.051097e+07
# 2020-06-01 17:00:00                                   2.885192e+07
# 2020-06-01 17:20:00                                   1.237955e+07
# 2020-06-01 17:40:00                                   2.061535e+07
# 2020-06-01 18:00:00                                   2.874824e+07
# 2020-06-01 18:20:00                                   1.194285e+07
# 2020-06-01 18:40:00                                   3.147257e+07
# 2020-06-01 19:00:00                                   3.406682e+07
# 2020-06-01 19:20:00                                   1.124918e+07
# 2020-06-01 19:40:00                                   1.949881e+07
# 2020-06-01 20:00:00                                   2.760551e+07
# 2020-06-01 20:20:00                                            NaN
# 2020-06-01 20:40:00                                            NaN
#
# 상품명                  LG전자 통돌이 세탁기 TR14WK1(화이트)  [기간]제주바다자연산돔39마리  \
# 방송일시
# 2020-06-01 03:20:00               9.973098e+06      1.198870e+07
# 2020-06-01 03:40:00               2.098150e+07      1.911104e+07
# 2020-06-01 04:00:00               2.797635e+07      2.815382e+07
# 2020-06-01 04:20:00               1.120424e+07      1.578313e+07
# 2020-06-01 04:40:00               2.470022e+07      2.470386e+07
# 2020-06-01 05:00:00               2.872339e+07      2.666609e+07
# 2020-06-01 05:20:00               1.106030e+07      1.756190e+07
# 2020-06-01 05:40:00               2.533999e+07      2.469588e+07
# 2020-06-01 06:00:00               2.999488e+07      2.622618e+07
# 2020-06-01 06:20:00               2.562009e+07      2.456074e+07
# 2020-06-01 06:40:00               3.029664e+07      2.651402e+07
# 2020-06-01 07:00:00               1.130476e+07      1.766327e+07
# 2020-06-01 07:20:00               1.130476e+07      1.773425e+07
# 2020-06-01 07:40:00               2.613518e+07      2.433742e+07
# 2020-06-01 08:00:00               2.961224e+07      2.705807e+07
# 2020-06-01 08:20:00               1.139047e+07      1.766995e+07
# 2020-06-01 08:40:00               2.649673e+07      2.419856e+07
# 2020-06-01 09:00:00               2.961224e+07      2.785626e+07
# 2020-06-01 09:20:00               1.124547e+07      1.811134e+07
# 2020-06-01 09:40:00               2.628916e+07      2.445497e+07
# 2020-06-01 10:00:00               2.969979e+07      2.849167e+07
# 2020-06-01 12:20:00               1.178725e+07      1.762366e+07
# 2020-06-01 12:40:00               2.641889e+07      2.452759e+07
# 2020-06-01 13:00:00               3.065879e+07      2.861558e+07
# 2020-06-01 13:20:00               1.193417e+07      1.817190e+07
# 2020-06-01 13:40:00               2.676231e+07      2.986462e+07
# 2020-06-01 14:00:00               3.067176e+07      3.463863e+07
# 2020-06-01 14:20:00               1.189466e+07      1.872610e+07
# 2020-06-01 14:40:00               2.617629e+07      2.460941e+07
# 2020-06-01 15:00:00               3.093372e+07      2.843875e+07
# 2020-06-01 15:20:00               1.251260e+07      1.808257e+07
# 2020-06-01 15:40:00               3.620064e+07      2.460128e+07
# 2020-06-01 16:00:00               3.436213e+07      2.785502e+07
# 2020-06-01 16:20:00               1.202395e+07      1.753451e+07
# 2020-06-01 16:40:00               2.664188e+07      2.430373e+07
# 2020-06-01 17:00:00               3.161717e+07      2.834347e+07
# 2020-06-01 17:20:00               1.187645e+07      1.760033e+07
# 2020-06-01 17:40:00               2.681214e+07      2.461741e+07
# 2020-06-01 18:00:00               3.161701e+07      2.969301e+07
# 2020-06-01 18:20:00               1.140106e+07      1.764663e+07
# 2020-06-01 18:40:00               2.721943e+07      2.449039e+07
# 2020-06-01 19:00:00               3.162238e+07      2.966868e+07
# 2020-06-01 19:20:00               1.068699e+07      1.785184e+07
# 2020-06-01 19:40:00               2.540753e+07      2.306072e+07
# 2020-06-01 20:00:00               3.002517e+07      2.834938e+07
# 2020-06-01 20:20:00                        NaN               NaN
# 2020-06-01 20:40:00                        NaN               NaN
#
# 상품명                    램프쿡 자동회전냄비  바비리스 퍼펙트 볼륨스타일러  벨레즈온 심리스 원피스 4종 패키지  \
# 방송일시
# 2020-06-01 03:20:00  1.225063e+07     6.977548e+06         6.190926e+06
# 2020-06-01 03:40:00  1.456490e+07     2.021403e+07         1.779102e+07
# 2020-06-01 04:00:00  2.305493e+07     2.435775e+07         2.387538e+07
# 2020-06-01 04:20:00  1.374387e+07     8.142480e+06         6.939347e+06
# 2020-06-01 04:40:00  1.625526e+07     2.034347e+07         1.779084e+07
# 2020-06-01 05:00:00  2.273344e+07     2.494568e+07         2.242021e+07
# 2020-06-01 05:20:00  1.331830e+07     1.250573e+07         6.998076e+06
# 2020-06-01 05:40:00  1.684304e+07     2.078948e+07         1.753128e+07
# 2020-06-01 06:00:00  2.415124e+07     2.523818e+07         2.317860e+07
# 2020-06-01 06:20:00  2.101048e+07     1.922809e+07         1.793230e+07
# 2020-06-01 06:40:00  2.669120e+07     2.577033e+07         2.353320e+07
# 2020-06-01 07:00:00  1.399655e+07     8.245136e+06         7.044105e+06
# 2020-06-01 07:20:00  1.394615e+07     8.245136e+06         1.252108e+07
# 2020-06-01 07:40:00  1.800946e+07     2.038264e+07         2.191129e+07
# 2020-06-01 08:00:00  2.451059e+07     2.546092e+07         2.692425e+07
# 2020-06-01 08:20:00  1.370428e+07     8.277369e+06         7.017837e+06
# 2020-06-01 08:40:00  1.801066e+07     2.039018e+07         1.872412e+07
# 2020-06-01 09:00:00  2.495555e+07     2.506262e+07         2.455103e+07
# 2020-06-01 09:20:00  1.342746e+07     8.436158e+06         7.152465e+06
# 2020-06-01 09:40:00  1.786846e+07     1.996088e+07         1.834072e+07
# 2020-06-01 10:00:00  2.564118e+07     2.580298e+07         2.539949e+07
# 2020-06-01 12:20:00  1.381806e+07     8.428069e+06         7.145606e+06
# 2020-06-01 12:40:00  1.787144e+07     2.003097e+07         1.880509e+07
# 2020-06-01 13:00:00  2.578327e+07     2.608710e+07         2.575959e+07
# 2020-06-01 13:20:00  1.377160e+07     8.493135e+06         7.200772e+06
# 2020-06-01 13:40:00  1.790189e+07     2.006132e+07         1.891484e+07
# 2020-06-01 14:00:00  2.579569e+07     2.563804e+07         2.531617e+07
# 2020-06-01 14:20:00  1.373714e+07     8.493135e+06         7.200772e+06
# 2020-06-01 14:40:00  1.695318e+07     2.020370e+07         1.862860e+07
# 2020-06-01 15:00:00  2.613443e+07     2.566863e+07         2.534637e+07
# 2020-06-01 15:20:00  1.356606e+07     8.486490e+06         7.202645e+06
# 2020-06-01 15:40:00  1.690901e+07     2.010242e+07         1.853521e+07
# 2020-06-01 16:00:00  2.533879e+07     2.586820e+07         2.466158e+07
# 2020-06-01 16:20:00  1.333605e+07     8.990845e+06         7.807972e+06
# 2020-06-01 16:40:00  1.659537e+07     2.042501e+07         1.842604e+07
# 2020-06-01 17:00:00  2.612100e+07     2.612045e+07         2.459390e+07
# 2020-06-01 17:20:00  1.322675e+07     8.990845e+06         7.807972e+06
# 2020-06-01 17:40:00  1.689101e+07     2.031614e+07         1.839763e+07
# 2020-06-01 18:00:00  2.675278e+07     2.600434e+07         2.450461e+07
# 2020-06-01 18:20:00  1.323833e+07     8.963042e+06         7.783828e+06
# 2020-06-01 18:40:00  1.721443e+07     2.048618e+07         1.860655e+07
# 2020-06-01 19:00:00  2.691678e+07     2.624790e+07         2.455288e+07
# 2020-06-01 19:20:00  1.260115e+07     8.862039e+06         7.658185e+06
# 2020-06-01 19:40:00  1.680161e+07     1.980102e+07         1.785287e+07
# 2020-06-01 20:00:00  2.714341e+07     2.602133e+07         2.408087e+07
# 2020-06-01 20:20:00           NaN              NaN                  NaN
# 2020-06-01 20:40:00           NaN              NaN                  NaN
#
# 상품명                  보루네오 델루나 유로탑 슬라이딩 LED침대 슈퍼싱글  보루네오 델루나 유로탑 슬라이딩 LED침대 퀸  \
# 방송일시
# 2020-06-01 03:20:00                  1.038671e+07               1.049936e+07
# 2020-06-01 03:40:00                  9.668406e+06               1.561568e+07
# 2020-06-01 04:00:00                  1.765125e+07               2.496496e+07
# 2020-06-01 04:20:00                  1.156634e+07               1.178898e+07
# 2020-06-01 04:40:00                  1.032686e+07               1.830974e+07
# 2020-06-01 05:00:00                  1.780064e+07               2.580902e+07
# 2020-06-01 05:20:00                  1.121746e+07               1.131984e+07
# 2020-06-01 05:40:00                  1.039859e+07               1.879634e+07
# 2020-06-01 06:00:00                  1.742854e+07               2.599821e+07
# 2020-06-01 06:20:00                  1.046454e+07               1.956457e+07
# 2020-06-01 06:40:00                  1.737849e+07               2.600396e+07
# 2020-06-01 07:00:00                  1.142004e+07               1.184580e+07
# 2020-06-01 07:20:00                  1.146706e+07               1.189456e+07
# 2020-06-01 07:40:00                  1.040157e+07               1.924552e+07
# 2020-06-01 08:00:00                  1.602096e+07               2.613150e+07
# 2020-06-01 08:20:00                  1.157510e+07               1.200663e+07
# 2020-06-01 08:40:00                  1.051693e+07               1.933519e+07
# 2020-06-01 09:00:00                  1.602096e+07               2.681517e+07
# 2020-06-01 09:20:00                  1.134129e+07               1.176411e+07
# 2020-06-01 09:40:00                  1.058630e+07               1.923621e+07
# 2020-06-01 10:00:00                  1.638312e+07               2.778617e+07
# 2020-06-01 12:20:00                  1.173408e+07               1.216718e+07
# 2020-06-01 12:40:00                  1.047725e+07               1.925033e+07
# 2020-06-01 13:00:00                  1.781674e+07               2.807827e+07
# 2020-06-01 13:20:00                  1.169463e+07               1.219445e+07
# 2020-06-01 13:40:00                  1.042582e+07               1.923792e+07
# 2020-06-01 14:00:00                  1.781674e+07               2.804104e+07
# 2020-06-01 14:20:00                  1.165809e+07               1.214980e+07
# 2020-06-01 14:40:00                  1.038623e+07               1.833407e+07
# 2020-06-01 15:00:00                  1.781674e+07               2.830669e+07
# 2020-06-01 15:20:00                  1.191309e+07               1.241556e+07
# 2020-06-01 15:40:00                  1.021753e+07               1.833407e+07
# 2020-06-01 16:00:00                  2.024788e+07               2.808828e+07
# 2020-06-01 16:20:00                  1.232565e+07               1.232778e+07
# 2020-06-01 16:40:00                  1.024688e+07               1.832207e+07
# 2020-06-01 17:00:00                  2.067733e+07               2.784314e+07
# 2020-06-01 17:20:00                  1.227212e+07               1.226428e+07
# 2020-06-01 17:40:00                  1.014498e+07               1.843934e+07
# 2020-06-01 18:00:00                  2.009906e+07               2.836392e+07
# 2020-06-01 18:20:00                  1.235423e+07               1.234634e+07
# 2020-06-01 18:40:00                  1.038574e+07               1.811022e+07
# 2020-06-01 19:00:00                  1.961575e+07               2.902846e+07
# 2020-06-01 19:20:00                  1.213232e+07               1.209070e+07
# 2020-06-01 19:40:00                  1.028272e+07               2.611078e+07
# 2020-06-01 20:00:00                  2.024890e+07               3.242463e+07
# 2020-06-01 20:20:00                           NaN                        NaN
# 2020-06-01 20:40:00                           NaN                        NaN
#
# 상품명                  보루네오 델루나 유로탑 슬라이딩 LED침대 킹  아키 라이크라 릴렉스 보정브라 패키지(뉴아키28차)  \
# 방송일시
# 2020-06-01 03:20:00               1.152831e+07                  1.054170e+07
# 2020-06-01 03:40:00               1.606144e+07                  1.563289e+07
# 2020-06-01 04:00:00               2.819134e+07                  2.372076e+07
# 2020-06-01 04:20:00               1.247088e+07                  1.132405e+07
# 2020-06-01 04:40:00               1.949504e+07                  1.713168e+07
# 2020-06-01 05:00:00               2.875659e+07                  2.211431e+07
# 2020-06-01 05:20:00               1.192241e+07                  1.156493e+07
# 2020-06-01 05:40:00               1.962510e+07                  1.764116e+07
# 2020-06-01 06:00:00               2.924893e+07                  2.419227e+07
# 2020-06-01 06:20:00               2.013978e+07                  1.847065e+07
# 2020-06-01 06:40:00               2.957755e+07                  2.407025e+07
# 2020-06-01 07:00:00               1.224330e+07                  1.175098e+07
# 2020-06-01 07:20:00               1.229370e+07                  1.188108e+07
# 2020-06-01 07:40:00               2.002894e+07                  1.891948e+07
# 2020-06-01 08:00:00               2.903375e+07                  2.507470e+07
# 2020-06-01 08:20:00               1.240953e+07                  1.205696e+07
# 2020-06-01 08:40:00               1.990457e+07                  1.886898e+07
# 2020-06-01 09:00:00               2.895624e+07                  2.536865e+07
# 2020-06-01 09:20:00               1.215886e+07                  1.337409e+07
# 2020-06-01 09:40:00               1.979771e+07                  2.450145e+07
# 2020-06-01 10:00:00               2.943693e+07                  2.613810e+07
# 2020-06-01 12:20:00               1.250427e+07                  1.235112e+07
# 2020-06-01 12:40:00               1.993133e+07                  1.876567e+07
# 2020-06-01 13:00:00               3.041047e+07                  2.617468e+07
# 2020-06-01 13:20:00               1.251773e+07                  1.247309e+07
# 2020-06-01 13:40:00               1.959152e+07                  1.870230e+07
# 2020-06-01 14:00:00               3.018443e+07                  2.611447e+07
# 2020-06-01 14:20:00               1.247190e+07                  1.241733e+07
# 2020-06-01 14:40:00               1.887327e+07                  1.778832e+07
# 2020-06-01 15:00:00               3.025495e+07                  2.638076e+07
# 2020-06-01 15:20:00               1.276424e+07                  1.241733e+07
# 2020-06-01 15:40:00               1.908160e+07                  1.778832e+07
# 2020-06-01 16:00:00               2.997144e+07                  2.557836e+07
# 2020-06-01 16:20:00               1.289801e+07                  1.241654e+07
# 2020-06-01 16:40:00               1.910672e+07                  1.776750e+07
# 2020-06-01 17:00:00               3.038126e+07                  2.609182e+07
# 2020-06-01 17:20:00               1.279407e+07                  1.246469e+07
# 2020-06-01 17:40:00               1.904352e+07                  1.825324e+07
# 2020-06-01 18:00:00               3.062916e+07                  2.640160e+07
# 2020-06-01 18:20:00               1.298699e+07                  1.232197e+07
# 2020-06-01 18:40:00               1.927993e+07                  1.873138e+07
# 2020-06-01 19:00:00               3.164007e+07                  2.710894e+07
# 2020-06-01 19:20:00               1.259172e+07                  1.165176e+07
# 2020-06-01 19:40:00               2.699144e+07                  1.916399e+07
# 2020-06-01 20:00:00               3.370175e+07                  2.689192e+07
# 2020-06-01 20:20:00                        NaN                           NaN
# 2020-06-01 20:40:00                        NaN                           NaN
#
# 상품명                  에이유플러스 슈퍼선스틱 1004(최저가)  올바로 문어발 샤워기 1+1  올바로 문어발 샤워기 1세트  \
# 방송일시
# 2020-06-01 03:20:00            6.882014e+06              NaN              NaN
# 2020-06-01 03:40:00            2.116893e+07              NaN              NaN
# 2020-06-01 04:00:00            2.534939e+07              NaN              NaN
# 2020-06-01 04:20:00            7.831993e+06              NaN              NaN
# 2020-06-01 04:40:00            1.922013e+07              NaN              NaN
# 2020-06-01 05:00:00            2.375113e+07              NaN              NaN
# 2020-06-01 05:20:00            7.807789e+06              NaN              NaN
# 2020-06-01 05:40:00            1.901947e+07              NaN              NaN
# 2020-06-01 06:00:00            2.454910e+07              NaN              NaN
# 2020-06-01 06:20:00            1.956641e+07              NaN              NaN
# 2020-06-01 06:40:00            2.529432e+07              NaN              NaN
# 2020-06-01 07:00:00            7.880937e+06              NaN              NaN
# 2020-06-01 07:20:00            7.841711e+06              NaN              NaN
# 2020-06-01 07:40:00            2.038920e+07              NaN              NaN
# 2020-06-01 08:00:00            2.565137e+07              NaN              NaN
# 2020-06-01 08:20:00            7.866530e+06              NaN              NaN
# 2020-06-01 08:40:00            2.026853e+07              NaN              NaN
# 2020-06-01 09:00:00            2.585250e+07              NaN              NaN
# 2020-06-01 09:20:00            8.017438e+06              NaN              NaN
# 2020-06-01 09:40:00            1.997019e+07              NaN              NaN
# 2020-06-01 10:00:00            2.679501e+07              NaN              NaN
# 2020-06-01 12:20:00            1.187260e+07              NaN              NaN
# 2020-06-01 12:40:00            2.386633e+07              NaN              NaN
# 2020-06-01 13:00:00            2.979003e+07              NaN              NaN
# 2020-06-01 13:20:00            8.074283e+06              NaN              NaN
# 2020-06-01 13:40:00            2.037598e+07              NaN              NaN
# 2020-06-01 14:00:00            2.673784e+07              NaN              NaN
# 2020-06-01 14:20:00            8.074283e+06              NaN              NaN
# 2020-06-01 14:40:00            2.017529e+07              NaN              NaN
# 2020-06-01 15:00:00            2.668007e+07              NaN              NaN
# 2020-06-01 15:20:00            8.076059e+06              NaN              NaN
# 2020-06-01 15:40:00            2.021614e+07              NaN              NaN
# 2020-06-01 16:00:00            2.627498e+07              NaN              NaN
# 2020-06-01 16:20:00            8.579674e+06              NaN              NaN
# 2020-06-01 16:40:00            2.021696e+07              NaN              NaN
# 2020-06-01 17:00:00            2.625561e+07              NaN              NaN
# 2020-06-01 17:20:00            8.596630e+06              NaN              NaN
# 2020-06-01 17:40:00            2.013704e+07              NaN              NaN
# 2020-06-01 18:00:00            2.642374e+07              NaN              NaN
# 2020-06-01 18:20:00            8.570047e+06              NaN              NaN
# 2020-06-01 18:40:00            2.040914e+07              NaN              NaN
# 2020-06-01 19:00:00            2.642374e+07              NaN              NaN
# 2020-06-01 19:20:00            8.477094e+06              NaN              NaN
# 2020-06-01 19:40:00            1.967185e+07              NaN              NaN
# 2020-06-01 20:00:00            2.616756e+07              NaN              NaN
# 2020-06-01 20:20:00                     NaN     2.072989e+07     1.244619e+06
# 2020-06-01 20:40:00                     NaN     2.896003e+07     5.562182e+06
#
# 상품명                  잭필드 남성  반팔셔츠 4종  코몽트 남성 티셔츠 8종(시즌1)  \
# 방송일시
# 2020-06-01 03:20:00     6.665804e+06        6.394238e+06
# 2020-06-01 03:40:00     1.576791e+07        1.575826e+07
# 2020-06-01 04:00:00     2.238805e+07        2.310614e+07
# 2020-06-01 04:20:00     8.255156e+06        7.821819e+06
# 2020-06-01 04:40:00     1.794579e+07        1.695000e+07
# 2020-06-01 05:00:00     2.276187e+07        2.200926e+07
# 2020-06-01 05:20:00     8.190892e+06        7.853238e+06
# 2020-06-01 05:40:00     1.754567e+07        1.691829e+07
# 2020-06-01 06:00:00     2.271961e+07        2.179650e+07
# 2020-06-01 06:20:00     1.768352e+07        1.685695e+07
# 2020-06-01 06:40:00     2.310996e+07        2.231505e+07
# 2020-06-01 07:00:00     8.500165e+06        7.859881e+06
# 2020-06-01 07:20:00     8.492934e+06        7.859881e+06
# 2020-06-01 07:40:00     1.832143e+07        1.727022e+07
# 2020-06-01 08:00:00     2.380836e+07        2.252332e+07
# 2020-06-01 08:20:00     8.443152e+06        7.890608e+06
# 2020-06-01 08:40:00     1.835173e+07        1.736480e+07
# 2020-06-01 09:00:00     2.412861e+07        2.279709e+07
# 2020-06-01 09:20:00     8.586278e+06        8.094238e+06
# 2020-06-01 09:40:00     1.777622e+07        1.698136e+07
# 2020-06-01 10:00:00     2.482723e+07        2.345716e+07
# 2020-06-01 12:20:00     8.517751e+06        8.118734e+06
# 2020-06-01 12:40:00     1.828603e+07        1.741046e+07
# 2020-06-01 13:00:00     2.505609e+07        2.348131e+07
# 2020-06-01 13:20:00     8.552261e+06        8.151628e+06
# 2020-06-01 13:40:00     1.827005e+07        1.751983e+07
# 2020-06-01 14:00:00     2.493834e+07        2.359710e+07
# 2020-06-01 14:20:00     8.526940e+06        8.098998e+06
# 2020-06-01 14:40:00     1.811042e+07        1.747709e+07
# 2020-06-01 15:00:00     2.496809e+07        2.361123e+07
# 2020-06-01 15:20:00     8.606254e+06        8.092661e+06
# 2020-06-01 15:40:00     1.793224e+07        1.732130e+07
# 2020-06-01 16:00:00     2.506257e+07        2.351211e+07
# 2020-06-01 16:20:00     9.133736e+06        1.028607e+07
# 2020-06-01 16:40:00     1.836885e+07        1.886122e+07
# 2020-06-01 17:00:00     2.506095e+07        2.276567e+07
# 2020-06-01 17:20:00     9.121379e+06        8.598694e+06
# 2020-06-01 17:40:00     1.814023e+07        1.755239e+07
# 2020-06-01 18:00:00     2.538231e+07        2.335081e+07
# 2020-06-01 18:20:00     9.139410e+06        8.572104e+06
# 2020-06-01 18:40:00     1.857406e+07        1.797216e+07
# 2020-06-01 19:00:00     2.546395e+07        2.342592e+07
# 2020-06-01 19:20:00     9.016789e+06        8.334531e+06
# 2020-06-01 19:40:00     1.802700e+07        1.739353e+07
# 2020-06-01 20:00:00     2.468223e+07        2.282928e+07
# 2020-06-01 20:20:00              NaN                 NaN
# 2020-06-01 20:40:00              NaN                 NaN
#
# 상품명                  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티  파격가 노비타 스마트 비데 무료설치(변기세정제)  \
# 방송일시
# 2020-06-01 03:20:00          1.126736e+07                1.061747e+07
# 2020-06-01 03:40:00          1.531797e+07                1.471753e+07
# 2020-06-01 04:00:00          2.627013e+07                2.050933e+07
# 2020-06-01 04:20:00          1.308188e+07                1.176061e+07
# 2020-06-01 04:40:00          2.162427e+07                1.660294e+07
# 2020-06-01 05:00:00          2.602392e+07                2.299524e+07
# 2020-06-01 05:20:00          1.191092e+07                1.158143e+07
# 2020-06-01 05:40:00          1.650231e+07                1.721841e+07
# 2020-06-01 06:00:00          2.568972e+07                2.345640e+07
# 2020-06-01 06:20:00          1.691352e+07                1.805466e+07
# 2020-06-01 06:40:00          2.603958e+07                2.441616e+07
# 2020-06-01 07:00:00          1.247793e+07                1.211928e+07
# 2020-06-01 07:20:00          1.254283e+07                1.208007e+07
# 2020-06-01 07:40:00          1.755827e+07                1.808609e+07
# 2020-06-01 08:00:00          2.673674e+07                2.320301e+07
# 2020-06-01 08:20:00          1.225067e+07                1.219389e+07
# 2020-06-01 08:40:00          1.744393e+07                1.838022e+07
# 2020-06-01 09:00:00          2.697854e+07                2.323005e+07
# 2020-06-01 09:20:00          1.200321e+07                1.191003e+07
# 2020-06-01 09:40:00          1.716071e+07                1.841299e+07
# 2020-06-01 10:00:00          2.786755e+07                2.380085e+07
# 2020-06-01 12:20:00          1.226199e+07                1.230491e+07
# 2020-06-01 12:40:00          1.720195e+07                1.802229e+07
# 2020-06-01 13:00:00          2.770572e+07                2.403715e+07
# 2020-06-01 13:20:00          1.222075e+07                1.226354e+07
# 2020-06-01 13:40:00          1.722801e+07                1.805816e+07
# 2020-06-01 14:00:00          2.758386e+07                2.418366e+07
# 2020-06-01 14:20:00          1.218563e+07                1.222523e+07
# 2020-06-01 14:40:00          1.664976e+07                1.741790e+07
# 2020-06-01 15:00:00          2.757459e+07                2.428201e+07
# 2020-06-01 15:20:00          1.211577e+07                1.243970e+07
# 2020-06-01 15:40:00          1.660638e+07                1.739474e+07
# 2020-06-01 16:00:00          2.744257e+07                2.415477e+07
# 2020-06-01 16:20:00          1.184448e+07                1.231426e+07
# 2020-06-01 16:40:00          1.644620e+07                1.706152e+07
# 2020-06-01 17:00:00          2.771319e+07                2.452997e+07
# 2020-06-01 17:20:00          1.174750e+07                1.272425e+07
# 2020-06-01 17:40:00          1.675133e+07                2.238839e+07
# 2020-06-01 18:00:00          2.815028e+07                2.629250e+07
# 2020-06-01 18:20:00          1.171724e+07                1.231686e+07
# 2020-06-01 18:40:00          1.707208e+07                1.696327e+07
# 2020-06-01 19:00:00          2.841394e+07                2.563456e+07
# 2020-06-01 19:20:00          1.107464e+07                1.166207e+07
# 2020-06-01 19:40:00          1.675035e+07                1.675510e+07
# 2020-06-01 20:00:00          2.891835e+07                2.477297e+07
# 2020-06-01 20:20:00                   NaN                         NaN
# 2020-06-01 20:40:00                   NaN                         NaN
#
# 상품명                  한라궁 황칠 제주오메기떡 2종 40개 (호박오메기20봉+팥오메기20봉)  \
# 방송일시
# 2020-06-01 03:20:00                             5.870533e+06
# 2020-06-01 03:40:00                             1.361056e+07
# 2020-06-01 04:00:00                             1.353398e+07
# 2020-06-01 04:20:00                             5.856740e+06
# 2020-06-01 04:40:00                             1.167290e+07
# 2020-06-01 05:00:00                             1.176736e+07
# 2020-06-01 05:20:00                             5.855167e+06
# 2020-06-01 05:40:00                             1.176659e+07
# 2020-06-01 06:00:00                             1.192587e+07
# 2020-06-01 06:20:00                             1.197102e+07
# 2020-06-01 06:40:00                             1.247664e+07
# 2020-06-01 07:00:00                             6.259252e+06
# 2020-06-01 07:20:00                             6.270153e+06
# 2020-06-01 07:40:00                             1.226080e+07
# 2020-06-01 08:00:00                             1.255477e+07
# 2020-06-01 08:20:00                             6.590792e+06
# 2020-06-01 08:40:00                             1.235725e+07
# 2020-06-01 09:00:00                             1.266268e+07
# 2020-06-01 09:20:00                             6.542236e+06
# 2020-06-01 09:40:00                             1.210132e+07
# 2020-06-01 10:00:00                             1.246296e+07
# 2020-06-01 12:20:00                             6.974865e+06
# 2020-06-01 12:40:00                             1.214122e+07
# 2020-06-01 13:00:00                             1.267837e+07
# 2020-06-01 13:20:00                             7.042298e+06
# 2020-06-01 13:40:00                             1.215275e+07
# 2020-06-01 14:00:00                             1.258738e+07
# 2020-06-01 14:20:00                             7.038293e+06
# 2020-06-01 14:40:00                             1.167992e+07
# 2020-06-01 15:00:00                             1.293119e+07
# 2020-06-01 15:20:00                             6.665039e+06
# 2020-06-01 15:40:00                             1.210611e+07
# 2020-06-01 16:00:00                             1.256491e+07
# 2020-06-01 16:20:00                             5.607160e+06
# 2020-06-01 16:40:00                             1.202124e+07
# 2020-06-01 17:00:00                             1.255419e+07
# 2020-06-01 17:20:00                             5.595325e+06
# 2020-06-01 17:40:00                             1.187132e+07
# 2020-06-01 18:00:00                             1.255419e+07
# 2020-06-01 18:20:00                             5.573642e+06
# 2020-06-01 18:40:00                             1.185592e+07
# 2020-06-01 19:00:00                             1.242046e+07
# 2020-06-01 19:20:00                             5.562901e+06
# 2020-06-01 19:40:00                             1.154913e+07
# 2020-06-01 20:00:00                             1.243219e+07
# 2020-06-01 20:20:00                                      NaN
# 2020-06-01 20:40:00                                      NaN
#
# 상품명                  한라궁 황칠 제주오메기떡 40개 (60g * 40봉)
# 방송일시
# 2020-06-01 03:20:00                   1.208982e+07
# 2020-06-01 03:40:00                   1.831642e+07
# 2020-06-01 04:00:00                   2.871575e+07
# 2020-06-01 04:20:00                   1.828459e+07
# 2020-06-01 04:40:00                   2.882558e+07
# 2020-06-01 05:00:00                   3.110051e+07
# 2020-06-01 05:20:00                   2.241012e+07
# 2020-06-01 05:40:00                   2.924742e+07
# 2020-06-01 06:00:00                   3.145504e+07
# 2020-06-01 06:20:00                   2.934366e+07
# 2020-06-01 06:40:00                   3.334090e+07
# 2020-06-01 07:00:00                   2.182488e+07
# 2020-06-01 07:20:00                   2.268642e+07
# 2020-06-01 07:40:00                   3.016503e+07
# 2020-06-01 08:00:00                   3.279202e+07
# 2020-06-01 08:20:00                   2.293465e+07
# 2020-06-01 08:40:00                   3.002567e+07
# 2020-06-01 09:00:00                   3.294260e+07
# 2020-06-01 09:20:00                   2.254241e+07
# 2020-06-01 09:40:00                   2.988399e+07
# 2020-06-01 10:00:00                   3.408295e+07
# 2020-06-01 12:20:00                   2.201734e+07
# 2020-06-01 12:40:00                   2.989844e+07
# 2020-06-01 13:00:00                   3.402021e+07
# 2020-06-01 13:20:00                   2.155939e+07
# 2020-06-01 13:40:00                   3.032652e+07
# 2020-06-01 14:00:00                   3.339708e+07
# 2020-06-01 14:20:00                   2.242447e+07
# 2020-06-01 14:40:00                   3.341417e+07
# 2020-06-01 15:00:00                   3.648519e+07
# 2020-06-01 15:20:00                   2.311487e+07
# 2020-06-01 15:40:00                   3.031167e+07
# 2020-06-01 16:00:00                   3.291628e+07
# 2020-06-01 16:20:00                   2.243089e+07
# 2020-06-01 16:40:00                   2.957155e+07
# 2020-06-01 17:00:00                   3.445239e+07
# 2020-06-01 17:20:00                   2.297808e+07
# 2020-06-01 17:40:00                   2.972446e+07
# 2020-06-01 18:00:00                   3.594931e+07
# 2020-06-01 18:20:00                   2.365246e+07
# 2020-06-01 18:40:00                   2.982815e+07
# 2020-06-01 19:00:00                   3.610877e+07
# 2020-06-01 19:20:00                   2.391881e+07
# 2020-06-01 19:40:00                   2.768062e+07
# 2020-06-01 20:00:00                   3.414577e+07
# 2020-06-01 20:20:00                            NaN
# 2020-06-01 20:40:00                            NaN

# %%
all_time[['방송일시','상품명','취급액']]
# Out:
#                     방송일시                        상품명           취급액
# 0    2020-06-01 03:20:00            잭필드 남성  반팔셔츠 4종  6.665804e+06
# 1    2020-06-01 03:40:00            잭필드 남성  반팔셔츠 4종  1.576791e+07
# 2    2020-06-01 04:00:00            잭필드 남성  반팔셔츠 4종  2.238805e+07
# 3    2020-06-01 03:20:00       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티  1.126736e+07
# 4    2020-06-01 03:40:00       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티  1.531797e+07
# ..                   ...                        ...           ...
# 899  2020-06-01 20:00:00  보루네오 델루나 유로탑 슬라이딩 LED침대 킹  3.370175e+07
# 900  2020-06-01 20:20:00            올바로 문어발 샤워기 1+1  2.072989e+07
# 901  2020-06-01 20:20:00            올바로 문어발 샤워기 1세트  1.244619e+06
# 902  2020-06-01 20:40:00            올바로 문어발 샤워기 1+1  2.896003e+07
# 903  2020-06-01 20:40:00            올바로 문어발 샤워기 1세트  5.562182e+06
#
# [904 rows x 3 columns]

# %% [markdown]
# # 지금까지 예측값을 넣어줬는데 같은 작업 반복해 원래 시간 (3시간 당긴거)에 맞도록 새로운 데이터를 병합시킵니다. 생각해보니 그냥 원래 데이터에서 x + delta 해줘도 되는데 괜히 개고생한것같습니다.

# %%
submission = pd.read_csv('/gdrive/My Drive/test_new.csv')
submission = submission[submission.상품군 != '무형']

submission = submission.iloc[:64]

# %%
submission = make_cast_time(submission)
submission['index'] = 1
for i in range(1, len(submission)):
    if (submission['cast_count'][i] == 1) & (submission['방송일시'][i] != submission['방송일시'][i-1]):
        submission['index'][i] = submission['index'][i-1] +1
    else:
        submission['index'][i] = submission['index'][i-1]
print(submission.shape)

tmp = submission.groupby('index').max()[['cast_count']].reset_index()
tmp.rename({'cast_count':'time'}, axis=1, inplace= True)
submission = pd.merge(submission, tmp, on='index', how='left')
submission
# Out:
# (64, 14)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                 방송일시  노출(분)    마더코드    상품코드                        상품명   상품군  \
# 0    2020-06-01 6:20   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 1    2020-06-01 6:40   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 2    2020-06-01 7:00   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 3    2020-06-01 7:20   20.0  100445  202278       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    속옷
# 4    2020-06-01 7:40   20.0  100445  202278       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    속옷
# ..               ...    ...     ...     ...                        ...   ...
# 59  2020-06-01 23:00   20.0  100205  200730  보루네오 델루나 유로탑 슬라이딩 LED침대 킹    가구
# 60  2020-06-01 23:20   20.0  100320  201016            올바로 문어발 샤워기 1+1  생활용품
# 61  2020-06-01 23:20   20.0  100320  201017            올바로 문어발 샤워기 1세트  생활용품
# 62  2020-06-01 23:40   20.0  100320  201016            올바로 문어발 샤워기 1+1  생활용품
# 63  2020-06-01 23:40   20.0  100320  201017            올바로 문어발 샤워기 1세트  생활용품
#
#          판매단가 취급액  cast_time  cast_count  cast_time_sum  cast_count_sum  \
# 0     59,800    0       20.0           1           60.0             3.0
# 1     59,800    0       40.0           2           60.0             3.0
# 2     59,800    0       60.0           3           60.0             3.0
# 3     69,900    0       20.0           1           60.0             3.0
# 4     69,900    0       40.0           2           60.0             3.0
# ..        ...  ..        ...         ...            ...             ...
# 59   648,000    0       60.0           3           60.0             3.0
# 60    54,900    0       20.0           1           40.0             2.0
# 61    28,900    0       20.0           1           40.0             2.0
# 62    54,900    0       40.0           2           40.0             2.0
# 63    28,900    0       40.0           2           40.0             2.0
#
#     cast_time_ratio  index  time
# 0          0.333333      1     3
# 1          0.666667      1     3
# 2          1.000000      1     3
# 3          0.333333      2     3
# 4          0.666667      2     3
# ..              ...    ...   ...
# 59         1.000000     15     3
# 60         0.500000     16     2
# 61         0.500000     16     2
# 62         1.000000     16     2
# 63         1.000000     16     2
#
# [64 rows x 15 columns]

# %%
ind = np.sort(submission[submission['time'] == 3]['index'].unique())
time_li = []
for i in ind:
    time_li.append(np.sort(submission[submission['index'] == i]['방송일시'].unique()).tolist())
time_li
# Out:
# [['2020-06-01 6:20', '2020-06-01 6:40', '2020-06-01 7:00'],
#  ['2020-06-01 7:20', '2020-06-01 7:40', '2020-06-01 8:00'],
#  ['2020-06-01 8:20', '2020-06-01 8:40', '2020-06-01 9:00'],
#  ['2020-06-01 10:00', '2020-06-01 9:20', '2020-06-01 9:40'],
#  ['2020-06-01 10:20', '2020-06-01 10:40', '2020-06-01 11:00'],
#  ['2020-06-01 11:20', '2020-06-01 11:40', '2020-06-01 12:00'],
#  ['2020-06-01 12:20', '2020-06-01 12:40', '2020-06-01 13:00'],
#  ['2020-06-01 15:20', '2020-06-01 15:40', '2020-06-01 16:00'],
#  ['2020-06-01 16:20', '2020-06-01 16:40', '2020-06-01 17:00'],
#  ['2020-06-01 17:20', '2020-06-01 17:40', '2020-06-01 18:00'],
#  ['2020-06-01 18:20', '2020-06-01 18:40', '2020-06-01 19:00'],
#  ['2020-06-01 19:20', '2020-06-01 19:40', '2020-06-01 20:00'],
#  ['2020-06-01 20:20', '2020-06-01 20:40', '2020-06-01 21:00'],
#  ['2020-06-01 21:20', '2020-06-01 21:40', '2020-06-01 22:00'],
#  ['2020-06-01 22:20', '2020-06-01 22:40', '2020-06-01 23:00']]

# %%
new1 = pd.DataFrame()
for i in range(len(submission[submission['time'] == 3]['index'].unique())):
    tmp = submission[submission['time'] == 3].copy()
    tmp['방송일시'] = tmp['cast_count'].apply(lambda x: time_li[i][x-1])
    new1 = new1.append(tmp)
    new1.reset_index(drop=True, inplace=True)

# %%
ind = np.sort(submission[submission['time'] == 2]['index'].unique())
time_li = []
for i in ind:
    time_li.append(np.sort(submission[submission['index'] == i]['방송일시'].unique()).tolist())
time_li

new2 = pd.DataFrame()
for i in range(len(submission[submission['time'] == 2]['index'].unique())):
    tmp = submission[submission['time'] == 2].copy()
    tmp['방송일시'] = tmp['cast_count'].apply(lambda x: time_li[i][x-1])
    new2 = new2.append(tmp)
    new2.reset_index(drop=True, inplace=True)

all_time = new1.append(new2)
all_time.reset_index(inplace=True, drop=True)
all_time
# Out:
#                  방송일시  노출(분)    마더코드    상품코드                        상품명   상품군  \
# 0     2020-06-01 6:20   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 1     2020-06-01 6:40   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 2     2020-06-01 7:00   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 3     2020-06-01 6:20   20.0  100445  202278       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    속옷
# 4     2020-06-01 6:40   20.0  100445  202278       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    속옷
# ..                ...    ...     ...     ...                        ...   ...
# 899  2020-06-01 23:00   20.0  100205  200730  보루네오 델루나 유로탑 슬라이딩 LED침대 킹    가구
# 900  2020-06-01 23:20   20.0  100320  201016            올바로 문어발 샤워기 1+1  생활용품
# 901  2020-06-01 23:20   20.0  100320  201017            올바로 문어발 샤워기 1세트  생활용품
# 902  2020-06-01 23:40   20.0  100320  201016            올바로 문어발 샤워기 1+1  생활용품
# 903  2020-06-01 23:40   20.0  100320  201017            올바로 문어발 샤워기 1세트  생활용품
#
#           판매단가 취급액  cast_time  cast_count  cast_time_sum  cast_count_sum  \
# 0      59,800    0       20.0           1           60.0             3.0
# 1      59,800    0       40.0           2           60.0             3.0
# 2      59,800    0       60.0           3           60.0             3.0
# 3      69,900    0       20.0           1           60.0             3.0
# 4      69,900    0       40.0           2           60.0             3.0
# ..         ...  ..        ...         ...            ...             ...
# 899   648,000    0       60.0           3           60.0             3.0
# 900    54,900    0       20.0           1           40.0             2.0
# 901    28,900    0       20.0           1           40.0             2.0
# 902    54,900    0       40.0           2           40.0             2.0
# 903    28,900    0       40.0           2           40.0             2.0
#
#      cast_time_ratio  index  time
# 0           0.333333      1     3
# 1           0.666667      1     3
# 2           1.000000      1     3
# 3           0.333333      2     3
# 4           0.666667      2     3
# ..               ...    ...   ...
# 899         1.000000     15     3
# 900         0.500000     16     2
# 901         0.500000     16     2
# 902         1.000000     16     2
# 903         1.000000     16     2
#
# [904 rows x 15 columns]

# %%
all_time['취급액'] = pred_exp
all_time[['방송일시','상품명','index','취급액','cast_count']]
# Out:
#                  방송일시                        상품명  index           취급액  \
# 0     2020-06-01 6:20            잭필드 남성  반팔셔츠 4종      1  6.665804e+06
# 1     2020-06-01 6:40            잭필드 남성  반팔셔츠 4종      1  1.576791e+07
# 2     2020-06-01 7:00            잭필드 남성  반팔셔츠 4종      1  2.238805e+07
# 3     2020-06-01 6:20       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티      2  1.126736e+07
# 4     2020-06-01 6:40       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티      2  1.531797e+07
# ..                ...                        ...    ...           ...
# 899  2020-06-01 23:00  보루네오 델루나 유로탑 슬라이딩 LED침대 킹     15  3.370175e+07
# 900  2020-06-01 23:20            올바로 문어발 샤워기 1+1     16  2.072989e+07
# 901  2020-06-01 23:20            올바로 문어발 샤워기 1세트     16  1.244619e+06
# 902  2020-06-01 23:40            올바로 문어발 샤워기 1+1     16  2.896003e+07
# 903  2020-06-01 23:40            올바로 문어발 샤워기 1세트     16  5.562182e+06
#
#      cast_count
# 0             1
# 1             2
# 2             3
# 3             1
# 4             2
# ..          ...
# 899           3
# 900           1
# 901           1
# 902           2
# 903           2
#
# [904 rows x 5 columns]

# %%
data = all_time[['방송일시','상품명','index','취급액','cast_count']].copy()

# %%
# 하루 동안 조합 가능한 방송 경우의 수가 몇개인지 보기 위해 ref를 만들어줍니다.
data['ref'] = 1
for i in range(1, len(data)):
    if data['index'][i] == data['index'][i-1]:
        data['ref'][i] = data['ref'][i-1]
    else:
        data['ref'][i] = data['ref'][i-1] + 1
data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  방송일시                        상품명  index           취급액  \
# 0     2020-06-01 6:20            잭필드 남성  반팔셔츠 4종      1  6.665804e+06
# 1     2020-06-01 6:40            잭필드 남성  반팔셔츠 4종      1  1.576791e+07
# 2     2020-06-01 7:00            잭필드 남성  반팔셔츠 4종      1  2.238805e+07
# 3     2020-06-01 6:20       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티      2  1.126736e+07
# 4     2020-06-01 6:40       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티      2  1.531797e+07
# ..                ...                        ...    ...           ...
# 899  2020-06-01 23:00  보루네오 델루나 유로탑 슬라이딩 LED침대 킹     15  3.370175e+07
# 900  2020-06-01 23:20            올바로 문어발 샤워기 1+1     16  2.072989e+07
# 901  2020-06-01 23:20            올바로 문어발 샤워기 1세트     16  1.244619e+06
# 902  2020-06-01 23:40            올바로 문어발 샤워기 1+1     16  2.896003e+07
# 903  2020-06-01 23:40            올바로 문어발 샤워기 1세트     16  5.562182e+06
#
#      cast_count  ref
# 0             1    1
# 1             2    1
# 2             3    1
# 3             1    2
# 4             2    2
# ..          ...  ...
# 899           3  225
# 900           1  226
# 901           1  226
# 902           2  226
# 903           2  226
#
# [904 rows x 6 columns]

# %%
# ref를 기준으로 해당 방송의 시작 시간, 취급액의 합, 상품명을 가져옵니다.
df1 = data.groupby('ref').first()[['방송일시']].reset_index()
df2 = data.groupby('ref').sum()[['취급액']].reset_index()
df3 = data.groupby('ref').first()[['상품명']].reset_index()

df = pd.DataFrame()
ref = np.sort(data['ref'].unique())
df['ref'] = ref

df = pd.merge(df,df1,on='ref', how='left')
df = pd.merge(df,df2,on='ref', how='left')
df = pd.merge(df,df3,on='ref', how='left')
df
# Out:
#      ref              방송일시           취급액  \
# 0      1   2020-06-01 6:20  4.482176e+07
# 1      2   2020-06-01 6:20  5.285547e+07
# 2      3   2020-06-01 6:20  5.154932e+07
# 3      4   2020-06-01 6:20  4.987047e+07
# 4      5   2020-06-01 6:20  4.785733e+07
# ..   ...               ...           ...
# 221  222  2020-06-01 22:20  4.855734e+07
# 222  223  2020-06-01 22:20  5.319015e+07
# 223  224  2020-06-01 22:20  1.520682e+08
# 224  225  2020-06-01 22:20  1.865750e+08
# 225  226  2020-06-01 23:20  5.649672e+07
#
#                                                상품명
# 0                                  잭필드 남성  반팔셔츠 4종
# 1                             쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티
# 2                                  바비리스 퍼펙트 볼륨스타일러
# 3                                       램프쿡 자동회전냄비
# 4                              벨레즈온 심리스 원피스 4종 패키지
# ..                                             ...
# 221                             코몽트 남성 티셔츠 8종(시즌1)
# 222                     파격가 노비타 스마트 비데 무료설치(변기세정제)
# 223  LG 울트라HD TV AI ThinQ(인공지능 씽큐) 55형 55UN7850KNA
# 224                   보루네오 델루나 유로탑 슬라이딩 LED침대 슈퍼싱글
# 225                                올바로 문어발 샤워기 1+1
#
# [226 rows x 4 columns]

# %%
# 09:20분이 10:00보다 빠르나 09가 10보다 오름차순에 밀려 이 시간대만 다시 조정해줍니다.
df['방송일시'] = df['방송일시'].apply(lambda x: x if x != '2020-06-01 10:00' else '2020-06-01 09:20')
#df = df[df['방송일시'] != '2020-06-01 10:00']

# 23시 20분은 유일하게 방송이 2회인 시간입니다. 다음날 20분까지 방송일수도 있으나 귀찮으니까 그냥 2개로 잡아줍니다.
# 23시 20분은 그냥 고정시켜두고 최적화 대상에서 제외시키겠습니다.
df = df[df['방송일시'] != '2020-06-01 23:20']
data = df.pivot_table(index='방송일시', columns='상품명', values='취급액')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
# 상품명               AAC 삼채포기김치 10kg  \
# 방송일시
# 2020-06-01 09:20     6.640526e+07
# 2020-06-01 10:20     6.679047e+07
# 2020-06-01 11:20     7.275723e+07
# 2020-06-01 12:20     6.718573e+07
# 2020-06-01 15:20     6.760485e+07
# 2020-06-01 16:20     6.785301e+07
# 2020-06-01 17:20     6.894826e+07
# 2020-06-01 18:20     6.784575e+07
# 2020-06-01 19:20     6.690339e+07
# 2020-06-01 20:20     6.805286e+07
# 2020-06-01 21:20     6.857892e+07
# 2020-06-01 22:20     6.707189e+07
# 2020-06-01 6:20      6.024328e+07
# 2020-06-01 7:20      6.308213e+07
# 2020-06-01 8:20      6.500267e+07
#
# 상품명               LG 울트라HD TV AI ThinQ(인공지능 씽큐) 55형 55UN7850KNA  \
# 방송일시
# 2020-06-01 09:20                                   1.539491e+08
# 2020-06-01 10:20                                   1.528953e+08
# 2020-06-01 11:20                                   1.537839e+08
# 2020-06-01 12:20                                   1.534809e+08
# 2020-06-01 15:20                                   1.575759e+08
# 2020-06-01 16:20                                   1.582323e+08
# 2020-06-01 17:20                                   1.571334e+08
# 2020-06-01 18:20                                   1.578968e+08
# 2020-06-01 19:20                                   1.595279e+08
# 2020-06-01 20:20                                   1.596996e+08
# 2020-06-01 21:20                                   1.917170e+08
# 2020-06-01 22:20                                   1.520682e+08
# 2020-06-01 6:20                                    1.404660e+08
# 2020-06-01 7:20                                    1.485777e+08
# 2020-06-01 8:20                                    1.513928e+08
#
# 상품명               LG전자 통돌이 세탁기 TR14WK1(화이트)  [기간]제주바다자연산돔39마리    램프쿡 자동회전냄비  \
# 방송일시
# 2020-06-01 09:20               6.722149e+07      6.873803e+07  6.169823e+07
# 2020-06-01 10:20               6.705219e+07      6.912974e+07  5.646619e+07
# 2020-06-01 11:20               6.749944e+07      6.972477e+07  5.667048e+07
# 2020-06-01 12:20               6.723442e+07      7.105798e+07  5.693710e+07
# 2020-06-01 15:20               6.886493e+07      7.076683e+07  5.747278e+07
# 2020-06-01 16:20               6.936824e+07      8.267514e+07  5.746918e+07
# 2020-06-01 17:20               6.900467e+07      7.177426e+07  5.682476e+07
# 2020-06-01 18:20               8.307537e+07      7.053887e+07  5.581386e+07
# 2020-06-01 19:20               7.028301e+07      7.018171e+07  5.605242e+07
# 2020-06-01 20:20               7.030561e+07      7.191075e+07  5.687054e+07
# 2020-06-01 21:20               7.024288e+07      7.180570e+07  5.736953e+07
# 2020-06-01 22:20               6.611969e+07      6.926194e+07  5.654618e+07
# 2020-06-01 6:20                5.893095e+07      5.925357e+07  4.987047e+07
# 2020-06-01 7:20                6.462784e+07      6.715308e+07  5.273257e+07
# 2020-06-01 8:20                6.639517e+07      6.848397e+07  5.431258e+07
#
# 상품명               바비리스 퍼펙트 볼륨스타일러  벨레즈온 심리스 원피스 4종 패키지  \
# 방송일시
# 2020-06-01 09:20     5.324355e+07         4.850961e+07
# 2020-06-01 10:20     5.408870e+07         6.135663e+07
# 2020-06-01 11:20     5.373017e+07         5.029300e+07
# 2020-06-01 12:20     5.420001e+07         5.089268e+07
# 2020-06-01 15:20     5.454614e+07         5.171029e+07
# 2020-06-01 16:20     5.419250e+07         5.143178e+07
# 2020-06-01 17:20     5.436547e+07         5.117574e+07
# 2020-06-01 18:20     5.445711e+07         5.039943e+07
# 2020-06-01 19:20     5.553631e+07         5.082792e+07
# 2020-06-01 20:20     5.531132e+07         5.071021e+07
# 2020-06-01 21:20     5.569713e+07         5.094326e+07
# 2020-06-01 22:20     5.468439e+07         4.959193e+07
# 2020-06-01 6:20      5.154932e+07         4.785733e+07
# 2020-06-01 7:20      5.343164e+07         4.715040e+07
# 2020-06-01 8:20      5.853339e+07         4.770795e+07
#
# 상품명               보루네오 델루나 유로탑 슬라이딩 LED침대 슈퍼싱글  아키 라이크라 릴렉스 보정브라 패키지(뉴아키28차)  \
# 방송일시
# 2020-06-01 09:20                  1.586380e+08                  5.429188e+07
# 2020-06-01 10:20                  1.565176e+08                  5.587526e+07
# 2020-06-01 11:20                  1.575403e+08                  5.629459e+07
# 2020-06-01 12:20                  1.584907e+08                  6.401364e+07
# 2020-06-01 15:20                  1.623699e+08                  5.729147e+07
# 2020-06-01 16:20                  1.617043e+08                  5.728986e+07
# 2020-06-01 17:20                  1.602517e+08                  5.658641e+07
# 2020-06-01 18:20                  1.630337e+08                  5.578401e+07
# 2020-06-01 19:20                  1.641288e+08                  5.627586e+07
# 2020-06-01 20:20                  1.640504e+08                  5.711952e+07
# 2020-06-01 21:20                  1.657477e+08                  5.816230e+07
# 2020-06-01 22:20                  1.865750e+08                  5.770767e+07
# 2020-06-01 6:20                   1.445675e+08                  4.989535e+07
# 2020-06-01 7:20                   1.563241e+08                  5.057005e+07
# 2020-06-01 8:20                   1.559554e+08                  5.339835e+07
#
# 상품명               에이유플러스 슈퍼선스틱 1004(최저가)  잭필드 남성  반팔셔츠 4종  코몽트 남성 티셔츠 8종(시즌1)  \
# 방송일시
# 2020-06-01 09:20            5.274166e+07     4.929364e+07        4.703188e+07
# 2020-06-01 10:20            5.388227e+07     5.062273e+07        4.765342e+07
# 2020-06-01 11:20            5.398756e+07     5.092349e+07        4.805250e+07
# 2020-06-01 12:20            5.478264e+07     5.118973e+07        4.853276e+07
# 2020-06-01 15:20            6.552896e+07     5.185987e+07        4.901051e+07
# 2020-06-01 16:20            5.518810e+07     5.176065e+07        4.926856e+07
# 2020-06-01 17:20            5.492964e+07     5.160545e+07        4.918731e+07
# 2020-06-01 18:20            5.456718e+07     5.160106e+07        4.892607e+07
# 2020-06-01 19:20            5.505224e+07     5.256354e+07        5.191296e+07
# 2020-06-01 20:20            5.515741e+07     5.264392e+07        4.950189e+07
# 2020-06-01 21:20            5.540293e+07     5.317742e+07        4.997018e+07
# 2020-06-01 22:20            5.431650e+07     5.172602e+07        4.855734e+07
# 2020-06-01 6:20             5.340033e+07     4.482176e+07        4.525864e+07
# 2020-06-01 7:20             5.080325e+07     4.896281e+07        4.678108e+07
# 2020-06-01 8:20             5.137636e+07     4.845618e+07        4.656802e+07
#
# 상품명               쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티  파격가 노비타 스마트 비데 무료설치(변기세정제)  \
# 방송일시
# 2020-06-01 09:20          5.543103e+07                5.459010e+07
# 2020-06-01 10:20          5.683783e+07                5.336917e+07
# 2020-06-01 11:20          5.667315e+07                5.380415e+07
# 2020-06-01 12:20          5.703148e+07                5.412388e+07
# 2020-06-01 15:20          5.716966e+07                5.436435e+07
# 2020-06-01 16:20          5.703263e+07                5.450537e+07
# 2020-06-01 17:20          5.640998e+07                5.392514e+07
# 2020-06-01 18:20          5.616472e+07                5.398921e+07
# 2020-06-01 19:20          5.600387e+07                5.390576e+07
# 2020-06-01 20:20          5.664912e+07                6.140513e+07
# 2020-06-01 21:20          5.720327e+07                5.491469e+07
# 2020-06-01 22:20          5.674334e+07                5.319015e+07
# 2020-06-01 6:20           5.285547e+07                4.584433e+07
# 2020-06-01 7:20           6.073007e+07                5.135880e+07
# 2020-06-01 8:20           5.410295e+07                5.225624e+07
#
# 상품명               한라궁 황칠 제주오메기떡 40개 (60g * 40봉)
# 방송일시
# 2020-06-01 09:20                   1.152163e+08
# 2020-06-01 10:20                   1.167292e+08
# 2020-06-01 11:20                   1.175136e+08
# 2020-06-01 12:20                   1.176159e+08
# 2020-06-01 15:20                   1.177304e+08
# 2020-06-01 16:20                   1.170654e+08
# 2020-06-01 17:20                   1.239732e+08
# 2020-06-01 18:20                   1.176789e+08
# 2020-06-01 19:20                   1.166374e+08
# 2020-06-01 20:20                   1.186727e+08
# 2020-06-01 21:20                   1.194394e+08
# 2020-06-01 22:20                   1.152894e+08
# 2020-06-01 6:20                    9.213705e+07
# 2020-06-01 7:20                    1.075077e+08
# 2020-06-01 8:20                    1.126602e+08

# %%
data.std().sort_values(ascending=False)
# Out:
# 상품명
# LG 울트라HD TV AI ThinQ(인공지능 씽큐) 55형 55UN7850KNA    1.091417e+07
# 보루네오 델루나 유로탑 슬라이딩 LED침대 슈퍼싱글                     8.717828e+06
# 한라궁 황칠 제주오메기떡 40개 (60g * 40봉)                    7.249877e+06
# LG전자 통돌이 세탁기 TR14WK1(화이트)                        4.970929e+06
# [기간]제주바다자연산돔39마리                                 4.638402e+06
# 아키 라이크라 릴렉스 보정브라 패키지(뉴아키28차)                     3.309951e+06
# 에이유플러스 슈퍼선스틱 1004(최저가)                           3.289189e+06
# 벨레즈온 심리스 원피스 4종 패키지                              3.288217e+06
# 파격가 노비타 스마트 비데 무료설치(변기세정제)                       3.079198e+06
# AAC 삼채포기김치 10kg                                  2.774375e+06
# 램프쿡 자동회전냄비                                       2.569643e+06
# 잭필드 남성  반팔셔츠 4종                                  2.127882e+06
# 쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티                             1.693514e+06
# 코몽트 남성 티셔츠 8종(시즌1)                               1.614193e+06
# 바비리스 퍼펙트 볼륨스타일러                                  1.508600e+06
# dtype: float64

# %%
data.T.std().sort_values(ascending=False)
# Out:
# 방송일시
# 2020-06-01 21:20    4.428406e+07
# 2020-06-01 22:20    4.170301e+07
# 2020-06-01 19:20    3.858081e+07
# 2020-06-01 18:20    3.851389e+07
# 2020-06-01 20:20    3.849580e+07
# 2020-06-01 17:20    3.831807e+07
# 2020-06-01 16:20    3.805692e+07
# 2020-06-01 15:20    3.778760e+07
# 2020-06-01 09:20    3.733673e+07
# 2020-06-01 11:20    3.702832e+07
# 2020-06-01 12:20    3.681848e+07
# 2020-06-01 8:20     3.670508e+07
# 2020-06-01 10:20    3.638625e+07
# 2020-06-01 7:20     3.620157e+07
# 2020-06-01 6:20     3.295081e+07
# dtype: float64

# %%
data.std().sort_values(ascending=False)[:8].index.tolist()
# Out:
# ['LG 울트라HD TV AI ThinQ(인공지능 씽큐) 55형 55UN7850KNA',
#  '보루네오 델루나 유로탑 슬라이딩 LED침대 슈퍼싱글',
#  '한라궁 황칠 제주오메기떡 40개 (60g * 40봉)',
#  'LG전자 통돌이 세탁기 TR14WK1(화이트)',
#  '[기간]제주바다자연산돔39마리',
#  '아키 라이크라 릴렉스 보정브라 패키지(뉴아키28차)',
#  '에이유플러스 슈퍼선스틱 1004(최저가)',
#  '벨레즈온 심리스 원피스 4종 패키지']

# %%
data.T.std().sort_values(ascending=False)[:8].index.tolist()
# Out:
# ['2020-06-01 21:20',
#  '2020-06-01 22:20',
#  '2020-06-01 19:20',
#  '2020-06-01 18:20',
#  '2020-06-01 20:20',
#  '2020-06-01 17:20',
#  '2020-06-01 16:20',
#  '2020-06-01 15:20']

# %%
# 한 번 궁금해서 표준편차가 높은 순서대로 데이터를 짤라서 해봤었습니다.
data1 = data.loc[data.T.std().sort_values(ascending=False)[:8].index.tolist(),data.std().sort_values(ascending=False)[:8].index.tolist()]
data2 = data.loc[data.T.std().sort_values(ascending=False)[8:].index.tolist(),data.std().sort_values(ascending=False)[8:].index.tolist()]

# %%
dic_data1 = data1.T.to_dict()
dic_data2 = data2.T.to_dict()
print(len(dic_data1))
print(len(dic_data2))
# Out:
# 8
# 7

# %%
# !pip install hungarian-algorithm
# Out:
# Collecting hungarian-algorithm
#   Downloading hungarian_algorithm-0.1.11-py3-none-any.whl (10 kB)
# Installing collected packages: hungarian-algorithm
# Successfully installed hungarian-algorithm-0.1.11

# %%
from hungarian_algorithm import algorithm

# %%
# algorithm.find_matching(dic_data, matching_type = 'max', return_type = 'list' )

# %%
opt1 = algorithm.find_matching(dic_data1, matching_type = 'max', return_type = 'list' )

# %%
opt2 = algorithm.find_matching(dic_data2, matching_type = 'max', return_type = 'list' )

# %%
opt1
# Out:
# [(('2020-06-01 22:20', '보루네오 델루나 유로탑 슬라이딩 LED침대 슈퍼싱글'), 186574975.13138175),
#  (('2020-06-01 16:20', '[기간]제주바다자연산돔39마리'), 82675141.0438192),
#  (('2020-06-01 19:20', '벨레즈온 심리스 원피스 4종 패키지'), 50827916.16221471),
#  (('2020-06-01 15:20', '에이유플러스 슈퍼선스틱 1004(최저가)'), 65528963.7216685),
#  (('2020-06-01 18:20', 'LG전자 통돌이 세탁기 TR14WK1(화이트)'), 83075367.71391127),
#  (('2020-06-01 17:20', '한라궁 황칠 제주오메기떡 40개 (60g * 40봉)'), 123973228.74142225),
#  (('2020-06-01 20:20', '아키 라이크라 릴렉스 보정브라 패키지(뉴아키28차)'), 57119524.93651408),
#  (('2020-06-01 21:20', 'LG 울트라HD TV AI ThinQ(인공지능 씽큐) 55형 55UN7850KNA'),
#   191716984.41286692)]

# %%
opt2
# Out:
# [(('2020-06-01 11:20', 'AAC 삼채포기김치 10kg'), 72757226.14001136),
#  (('2020-06-01 6:20', '코몽트 남성 티셔츠 8종(시즌1)'), 45258642.98978041),
#  (('2020-06-01 7:20', '쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티'), 60730067.6313303),
#  (('2020-06-01 10:20', '잭필드 남성  반팔셔츠 4종'), 50622728.28354572),
#  (('2020-06-01 8:20', '바비리스 퍼펙트 볼륨스타일러'), 58533394.751718126),
#  (('2020-06-01 09:20', '램프쿡 자동회전냄비'), 61698226.485848814),
#  (('2020-06-01 12:20', '파격가 노비타 스마트 비데 무료설치(변기세정제)'), 54123882.38412448)]

# %%
values1 = 0
for i in opt1:
    values1 += i[1]
values1
# Out:
# 841492101.8637987

# %%
values2 = 0
for i in opt2:
    values2 += i[1]
values2
# Out:
# 403724168.6663591

# %%
opt_val = values1 + values2 + 5.649672e+07

# %% [markdown]
# # 멍청하게 원래 데이터의 취급액 합을 안구했으므로 다시 구하겠습니다.

# %%
submission = pd.read_csv('/gdrive/My Drive/test_new.csv')
submission = submission[submission.상품군 != '무형']

submission = submission.iloc[:64]
submission
# Out:
#                 방송일시  노출(분)    마더코드    상품코드                        상품명   상품군  \
# 0    2020-06-01 6:20   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 1    2020-06-01 6:40   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 2    2020-06-01 7:00   20.0  100650  201971            잭필드 남성  반팔셔츠 4종    의류
# 3    2020-06-01 7:20   20.0  100445  202278       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    속옷
# 4    2020-06-01 7:40   20.0  100445  202278       쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    속옷
# ..               ...    ...     ...     ...                        ...   ...
# 66  2020-06-01 23:00    NaN  100205  200730  보루네오 델루나 유로탑 슬라이딩 LED침대 킹    가구
# 67  2020-06-01 23:20   20.0  100320  201016            올바로 문어발 샤워기 1+1  생활용품
# 68  2020-06-01 23:20    NaN  100320  201017            올바로 문어발 샤워기 1세트  생활용품
# 69  2020-06-01 23:40   20.0  100320  201016            올바로 문어발 샤워기 1+1  생활용품
# 70  2020-06-01 23:40    NaN  100320  201017            올바로 문어발 샤워기 1세트  생활용품
#
#          판매단가  취급액
# 0     59,800   NaN
# 1     59,800   NaN
# 2     59,800   NaN
# 3     69,900   NaN
# 4     69,900   NaN
# ..        ...  ...
# 66   648,000   NaN
# 67    54,900   NaN
# 68    28,900   NaN
# 69    54,900   NaN
# 70    28,900   NaN
#
# [64 rows x 8 columns]

# %%
ori = pd.merge(submission, all_time[['방송일시','상품명','취급액']], on=['방송일시','상품명'], how='left')
ori.rename({'취급액_y':'취급액'}, axis=1, inplace=True)
del ori['취급액_x']
ori.isnull().sum()
# Out:
# 방송일시      0
# 노출(분)    17
# 마더코드      0
# 상품코드      0
# 상품명       0
# 상품군       0
# 판매단가      0
# 취급액       0
# dtype: int64

# %%
ori_val = ori['취급액'].sum()

# %%
print('최적화 값: {}'.format(opt_val))
print('기존 값: {}'.format(ori_val))
print('상승률: {}'.format(ori_val))
# Out:
# 최적화 값: 1301712990.5301578
# 기존 값: 1327270422.761019
# 상승률: 1327270422.761019

# %%
dic_data = data.T.to_dict()
print(len(dic_data))
# Out:
# 15

# %%
data.shape
# Out:
# (15, 15)

# %%
opt
# Out:
# [(('2020-06-01 22:20', '보루네오 델루나 유로탑 슬라이딩 LED침대 슈퍼싱글'), 186574975.13138175),
#  (('2020-06-01 16:20', '[기간]제주바다자연산돔39마리'), 82675141.0438192),
#  (('2020-06-01 19:20', '벨레즈온 심리스 원피스 4종 패키지'), 50827916.16221471),
#  (('2020-06-01 15:20', '에이유플러스 슈퍼선스틱 1004(최저가)'), 65528963.7216685),
#  (('2020-06-01 18:20', 'LG전자 통돌이 세탁기 TR14WK1(화이트)'), 83075367.71391127),
#  (('2020-06-01 17:20', '한라궁 황칠 제주오메기떡 40개 (60g * 40봉)'), 123973228.74142225),
#  (('2020-06-01 20:20', '아키 라이크라 릴렉스 보정브라 패키지(뉴아키28차)'), 57119524.93651408),
#  (('2020-06-01 21:20', 'LG 울트라HD TV AI ThinQ(인공지능 씽큐) 55형 55UN7850KNA'),
#   191716984.41286692)]

# %%
opt2
# Out:
# [(('2020-06-01 11:20', 'AAC 삼채포기김치 10kg'), 72757226.14001136),
#  (('2020-06-01 6:20', '코몽트 남성 티셔츠 8종(시즌1)'), 45258642.98978041),
#  (('2020-06-01 7:20', '쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티'), 60730067.6313303),
#  (('2020-06-01 10:20', '잭필드 남성  반팔셔츠 4종'), 50622728.28354572),
#  (('2020-06-01 8:20', '바비리스 퍼펙트 볼륨스타일러'), 58533394.751718126),
#  (('2020-06-01 09:20', '램프쿡 자동회전냄비'), 61698226.485848814),
#  (('2020-06-01 12:20', '파격가 노비타 스마트 비데 무료설치(변기세정제)'), 54123882.38412448)]

# %% [markdown]
# ## 사실 여기가 핵심입니다. data.T.std().sort_values(ascending=False)[:].index.tolist() 이거 때려버리면 사실상 변수 위치만 바뀌지 개수는 똑같습니다. 그런데 이렇게 하면 1초만에 다 돌아가는 기적이 발생합니다. 이유는 아직도 모르겠습니다.

# %%
data1 = (
    data
    .loc[data.T.std()
         .sort_values(ascending=False)[:]
         .index
         .tolist(),
         data.std()
         .sort_values(ascending=False)[:]
         .index.tolist()]
)

dic_data = data1.T.to_dict()

# %%
opt = algorithm.find_matching(dic_data, matching_type = 'max', return_type = 'list' )

# %%
opt
# Out:
# [(('2020-06-01 11:20', 'AAC 삼채포기김치 10kg'), 72757226.14001136),
#  (('2020-06-01 6:20', '코몽트 남성 티셔츠 8종(시즌1)'), 45258642.98978041),
#  (('2020-06-01 22:20', '보루네오 델루나 유로탑 슬라이딩 LED침대 슈퍼싱글'), 186574975.13138175),
#  (('2020-06-01 7:20', '쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티'), 60730067.6313303),
#  (('2020-06-01 16:20', '[기간]제주바다자연산돔39마리'), 82675141.0438192),
#  (('2020-06-01 15:20', '에이유플러스 슈퍼선스틱 1004(최저가)'), 65528963.7216685),
#  (('2020-06-01 8:20', '바비리스 퍼펙트 볼륨스타일러'), 58533394.751718126),
#  (('2020-06-01 18:20', 'LG전자 통돌이 세탁기 TR14WK1(화이트)'), 83075367.71391127),
#  (('2020-06-01 17:20', '한라궁 황칠 제주오메기떡 40개 (60g * 40봉)'), 123973228.74142225),
#  (('2020-06-01 09:20', '램프쿡 자동회전냄비'), 61698226.485848814),
#  (('2020-06-01 20:20', '파격가 노비타 스마트 비데 무료설치(변기세정제)'), 61405134.37022279),
#  (('2020-06-01 12:20', '아키 라이크라 릴렉스 보정브라 패키지(뉴아키28차)'), 64013643.944531366),
#  (('2020-06-01 10:20', '벨레즈온 심리스 원피스 4종 패키지'), 61356626.53624367),
#  (('2020-06-01 19:20', '잭필드 남성  반팔셔츠 4종'), 52563541.44318559),
#  (('2020-06-01 21:20', 'LG 울트라HD TV AI ThinQ(인공지능 씽큐) 55형 55UN7850KNA'),
#   191716984.41286692)]

# %%
values = 0
for i in opt:
    values += i[1]
values = values + 5.649672e+07
values
# Out:
# 1328357885.0579422

# %%
print('최적화 값: {}'.format(values))
print('기존 값: {}'.format(ori_val))
print('상승률: {}'.format(((values - ori_val)/ori_val)*100))
# Out:
# 최적화 값: 1328357885.0579422
# 기존 값: 1327270422.761019
# 상승률: 0.0819322331210392
