# 2574     식품     축산  축산가공식품  쇠고기양념육

# %%
import pandas as pd 
import numpy as np 
import re 
import os
import sys
import urllib.request
import json
from tabulate import tabulate

# %% [markdown]
# **<제품명에서 제거된 것 + 이에 사용한 정규표현식 ('|'로 구분)>**
#
# **1. 괄호를 포함 혹은 포함하지 않은 결제관련 정보(무이자, 일시불, 이자 등)**
#
#     \(?무이자\)?\s?|\(?일시불\)?\s?|\(?초특가\)?\s?|\(?무\)\s?|\(?유\)\s?|\(?일\)\s?
#
# **2. 제품명 맨 앞, 맨 끝에 붙어있는 괄호들 (40인치) (특상품) (초특가) 등은 제품 카테고리와 무방하다 생각하여 삭제**
#
#     \(.{1,10}\)$|^\(.?\)
#
# **3. ~패키지, ~종, 세트, n+n, 더블팩, 싱글팩 등 제품 수량단위와 관련한 것**
#
#     \s?패키지\s?|[0-9]+종.*|세트|더블팩|싱글팩|[0-9]{1,2}\+[0-9]{1,2}

# %% [markdown]
# # Preprocess (민수 ipynb 참고)

# %%
t = pd.read_excel('C:/Users/SHJ/Documents/GIS/Bigcon2020/data/01_제공데이터/2020 빅콘테스트 데이터분석분야-챔피언리그_2019년 실적데이터_v1_200818.xlsx', skiprows=1)
print(t.isnull().sum(),'\n')
t=t[t['상품군']!='무형']
print(t.isnull().sum(),'\n')
t[t['취급액'].isnull()]
t.취급액 = t.취급액.fillna(0)
print(t.isnull().sum())
t
# Out:
# 방송일시         0
# 노출(분)    16784
# 마더코드         0
# 상품코드         0
# 상품명          0
# 상품군          0
# 판매단가         0
# 취급액       2930
# dtype: int64
#
# 방송일시         0
# 노출(분)    16784
# 마더코드         0
# 상품코드         0
# 상품명          0
# 상품군          0
# 판매단가         0
# 취급액       1993
# dtype: int64
#
# 방송일시         0
# 노출(분)    16784
# 마더코드         0
# 상품코드         0
# 상품명          0
# 상품군          0
# 판매단가         0
# 취급액          0
# dtype: int64
#                      방송일시  노출(분)    마더코드    상품코드             상품명 상품군    판매단가  \
# 0     2019-01-01 06:00:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 1     2019-01-01 06:00:00    NaN  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 2     2019-01-01 06:20:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 3     2019-01-01 06:20:00    NaN  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 4     2019-01-01 06:40:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# ...                   ...    ...     ...     ...             ...  ..     ...
# 38299 2019-12-31 23:40:00    NaN  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
# 38300 2020-01-01 00:00:00   20.0  100448  201383  무이자쿠첸압력밥솥 10인용  주방  178000
# 38301 2020-01-01 00:00:00    NaN  100448  201390  일시불쿠첸압력밥솥 10인용  주방  168000
# 38302 2020-01-01 00:00:00    NaN  100448  201384   무이자쿠첸압력밥솥 6인용  주방  158000
# 38303 2020-01-01 00:00:00    NaN  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
#
#                취급액
# 0        2099000.0
# 1        4371000.0
# 2        3262000.0
# 3        6955000.0
# 4        6672000.0
# ...            ...
# 38299   10157000.0
# 38300   50929000.0
# 38301  104392000.0
# 38302   13765000.0
# 38303   46608000.0
#
# [37372 rows x 8 columns]

# %%
performance = pd.read_excel('C:/Users/SHJ/Documents/GIS/Bigcon2020/data/01_제공데이터/2020 빅콘테스트 데이터분석분야-챔피언리그_2019년 실적데이터_v1_200818.xlsx', skiprows=1)
ratings = pd.read_excel('C:/Users/SHJ/Documents/GIS/Bigcon2020/data/01_제공데이터/2020 빅콘테스트 데이터분석분야-챔피언리그_시청률 데이터.xlsx', skiprows=1)
performance = performance[performance['상품군']!='무형']
performance['취급액'] = performance['취급액'].fillna(0)
performance = performance.fillna(method='pad')
performance.drop(['마더코드','상품코드'], axis=1, inplace=True)
performance['방송일시_yymmdd'] = performance['방송일시'].apply(lambda x: str(x)[:10])
performance['방송일시_hhmmss'] = performance['방송일시'].apply(lambda x: str(x)[11:])

performance['seconds'] = performance['방송일시_hhmmss'].apply(lambda x: int(x[:2])*60 + int(x[3:5]))


performance.head()
# Out:
#                  방송일시  노출(분)            상품명 상품군   판매단가        취급액 방송일시_yymmdd  \
# 0 2019-01-01 06:00:00   20.0  테이트 남성 셀린니트3종  의류  39900  2099000.0  2019-01-01
# 1 2019-01-01 06:00:00   20.0  테이트 여성 셀린니트3종  의류  39900  4371000.0  2019-01-01
# 2 2019-01-01 06:20:00   20.0  테이트 남성 셀린니트3종  의류  39900  3262000.0  2019-01-01
# 3 2019-01-01 06:20:00   20.0  테이트 여성 셀린니트3종  의류  39900  6955000.0  2019-01-01
# 4 2019-01-01 06:40:00   20.0  테이트 남성 셀린니트3종  의류  39900  6672000.0  2019-01-01
#
#   방송일시_hhmmss  seconds
# 0    06:00:00      360
# 1    06:00:00      360
# 2    06:20:00      380
# 3    06:20:00      380
# 4    06:40:00      400

# %%
ratings = ratings.set_index('시간대')
ratings.mean(axis=1)
ratings.drop('월화수목금토일02:00-01:59', axis=0, inplace=True)

mean = ratings.mean(axis=1).values
ratings['mean'] = mean
ratings = ratings.reset_index()
ratings = ratings[['시간대','mean']]
ratings['시간대'] = ratings['시간대'].astype('datetime64[ns]')
ratings.set_index('시간대', inplace=True)

# 5단위로 시간대별 평균 집계
tmp = ratings[['mean']].resample('5T').mean().reset_index()
ratings = ratings.reset_index()
ratings = pd.merge(ratings, tmp, on='시간대', how='left')
ratings.head()

ratings.drop('mean_x', axis = 1, inplace= True)
ratings.rename({'mean_y':'ratings_mean'}, axis=1, inplace=True)
ratings['시간대'] = ratings['시간대'].astype(str)
ratings.head()

# 시간대에서 초단위 삭제
ratings['시간대'] = ratings['시간대'].apply(lambda x: x[-8:-3])
# 시분만 사용한 컬럼 생성
performance['방송일시_hhmm'] = performance['방송일시_hhmmss'].apply(lambda x: x[:-3])

performance = pd.merge(performance, ratings, left_on = '방송일시_hhmm', right_on = '시간대', how='left')
del performance['시간대']

performance.head()
# Out:
#                  방송일시  노출(분)            상품명 상품군   판매단가        취급액 방송일시_yymmdd  \
# 0 2019-01-01 06:00:00   20.0  테이트 남성 셀린니트3종  의류  39900  2099000.0  2019-01-01
# 1 2019-01-01 06:00:00   20.0  테이트 여성 셀린니트3종  의류  39900  4371000.0  2019-01-01
# 2 2019-01-01 06:20:00   20.0  테이트 남성 셀린니트3종  의류  39900  3262000.0  2019-01-01
# 3 2019-01-01 06:20:00   20.0  테이트 여성 셀린니트3종  의류  39900  6955000.0  2019-01-01
# 4 2019-01-01 06:40:00   20.0  테이트 남성 셀린니트3종  의류  39900  6672000.0  2019-01-01
#
#   방송일시_hhmmss  seconds 방송일시_hhmm  ratings_mean
# 0    06:00:00      360     06:00      0.002255
# 1    06:00:00      360     06:00      0.002255
# 2    06:20:00      380     06:20      0.002210
# 3    06:20:00      380     06:20      0.002210
# 4    06:40:00      400     06:40      0.001997

# %% [markdown]
# # 제품명 전처리

# %%
# 상품명 중복 제거
uniq_pname=performance['상품명'].unique()
print('\n<# of Unique pnameuct Name> : \n\t{}'.format(len(uniq_pname)))
np.set_printoptions(threshold=sys.maxsize)

# 추후 조합을 위해 전처리 이전 제품명과 이후 제품명을 저장합니다.
p_name = pd.DataFrame(data=uniq_pname, columns=['Before Process'])

# 제품명에서 불필요한 요소 전처리
ap=[]
re_stop = re.compile("""\([가-힣]{1,5}\+[가-힣]{1,5}\)|\(?무이자\)?\s?|\(?일시불\)?\s?|\(?초특가\)?\s?|\(?무\)\s?|\(?유\)\s?|\(?일\)\s?|무료체험|
|포함|국내[가-힣]+\s|무료설치|\s?신제품\s?|\s?패키지\s?|[0-9]+종|풀코디|set|SET|풀세트|[0-9]+세트|더블팩|싱글팩|[0-9]{1,2}\+[0-9]{1,2}|[0-9]{1,2}인용|[0-9]{1,2}박스|[0-9\.]{1,4}미터|[0-9\.]{1,4}kg|[0-9\.]{1,4}[kKgG]|[0-9]{1,3}[벌롤종단구대P개통병포미봉팩장gL매]|
|\s[0-9\.]{1,4}[Mm]|\(.{1,10}\)$|^\(.?\)|^[0-9]{2,4}\s|\s+[0-9]{2,4}\s|[0-9]{2,4}년\s|[0-9]{2,4}년형\s|시즌[0-9]|[0-9]{1,3}\%|\(.{1,20}\)$|기본형|고급형|오리지널|[대중소大中小]형|.{1,10}by|,|\s?총[0-9\s]|^[가-힣a-zA-Z]{3,3}의|
|S\/S|F\/W|f\/w|s\/s|[가-힣]+형\s|[슈퍼]{0,2}싱글|\s[SQK퀸킹]{1,2}\s|[SQK퀸킹]{1,2}$|[가-힣]{0,2}사이즈""")

remnants = re.compile('[",g\+lL-]\s|ml|_|\sx|[\[\]\］!"#$%&\'()*+,./:;<=>?@\^_`{|}~-]|\s종$|\s[0-9]+\s|\s{2,}')

for i in p_name['Before Process']:
    tmp = re_stop.sub(' ',i)
    tmp = tmp.strip()
    tmp = remnants.sub(' ',tmp)
    ap.append(tmp.strip())

# 전처리된 제품명 중복제거
p_name['After Process'] = ap
p_name.to_html('tmp.html')

ap = list(set(ap))

p_name
# Out:
# <# of Unique pnameuct Name> :
# 	1692
#                         Before Process                     After Process
# 0                        테이트 남성 셀린니트3종                       테이트 남성 셀린니트
# 1                        테이트 여성 셀린니트3종                       테이트 여성 셀린니트
# 2                     오모떼 레이스 파운데이션 브라                  오모떼 레이스 파운데이션 브라
# 3        CERINI by PAT 남성 소프트 기모 릴렉스팬츠               PAT 남성 소프트 기모 릴렉스팬츠
# 4                          보코 리버시블 무스탕                       보코 리버시블 무스탕
# ...                                ...                               ...
# 1687                     조방할매 낙곱새 6팩세트                       조방할매 낙곱새 세트
# 1688  파격가 니봇 무선 진공 물걸레 로봇청소기 +뉴헤어드라이어기  파격가 니봇 무선 진공 물걸레 로봇청소기  뉴헤어드라이어기
# 1689                        램프쿡 자동회전냄비                        램프쿡 자동회전냄비
# 1690               벨라홈 스마트 멀티포트 1+1 세트                   벨라홈 스마트 멀티포트 세트
# 1691                     코몽트 기모 터틀넥 5종                        코몽트 기모 터틀넥
#
# [1692 rows x 2 columns]

# %%
print(ap)
# Out:
# ['썸덱스 쉬룰 데일리 백팩 세트', '안드레아바나 리얼카이만 악어 바디 숄더백', '시크릿 라메종 볼륨 스프레이', '파뷔에 항균 뱀부 식기건조대', '테이트 남성 기모티셔츠', '멋진밥상 흥양농협 햅쌀', '프라다 자카드 토트백', '이동수골프 남성 썸머 밴딩팬츠', '브람스안마의자 럭셔리', '대웅모닝컴 굿템 스탠드선풍기', '해피콜IH양면팬', '헤스티지  여성 스타디움 자켓', '수련 무선 무릎 에어 온열 마사지기 SR823', 'USPA화이트라벨 남성모크넥세트', '젠트웰 남성 �
�이에어컨 6형 ARC06NQT', '매직쉐프 플랫타입 전자레인지', '보몽드 엘리 소프트플란넬 침구세트 SK', '한빛 페르시안스타일 셔닐 카페트 점보특', '삼성 UHD TVUN55RU7150FXKR', '월드컵 여성다이얼트레킹화세트', '더블유베일 소프트 마카롱 니트', '메이듀 여성 린넨 블렌디드 슬립온', '제주 한라봉  천혜향', '헤비추얼 여성 트렌치 맥코트', '루시헨느 레이스 홀리데이 란쥬', '레이프릴 풍기인견 힐링 란쥬', '파뷔에 더온 세라믹 냄비세트', '뷰티플렉스 풍기인견 원피스', '해피콜 X2싱크릴 분리가능 양면그릴', '푸마 코튼 라이크라 드로즈', 'RYN  린 남성 다이얼락 히트 웜 퍼 방한화', '오세득 본 갈비탕', '티젠 히비스커스 분말', '쿠첸 풀스텐 압력밥솥', '알비에로 마르티니 1A클라쎄 지오맵 호보백', 'The귀한 소한마리찜', '저스트 코튼 슬리머', '팜스프링스 SS 여성 여름 쿨팬츠', '에펨 여성 미들퍼부츠', '웰스락 원터치 슬라이드 특허 밀폐용기세트', '프라다 비텔로 라운드 토트 숄더백', '한국인 모유유래 다이어트 유산균 BNR17 비에날씬 12주', '에펨 남성 미들퍼부츠', 'AHC 스킨케어링 톤커버크림', '실크트리 풍기인견 쿨란쥬', '릴리젼 PK 남성 티셔츠세트', '제옥스 남성 가죽 스니커즈', '로벤탈 파스텔 후라이팬', '에델코첸 컬러스텐냄비 세트', '이누스바스 시공', 'USPA 남성 아동 반팔 폴로셔츠', '아이넥스 카세로 식기건조대', '벨레즈온 브라캡 심리스 원피스', '해피콜 크로커다일 IH 후라이팬', '로베르타 디 까메 ...

# %%
p_name
# Out:
#                         Before Process                     After Process
# 0                        테이트 남성 셀린니트3종                       테이트 남성 셀린니트
# 1                        테이트 여성 셀린니트3종                       테이트 여성 셀린니트
# 2                     오모떼 레이스 파운데이션 브라                  오모떼 레이스 파운데이션 브라
# 3        CERINI by PAT 남성 소프트 기모 릴렉스팬츠               PAT 남성 소프트 기모 릴렉스팬츠
# 4                          보코 리버시블 무스탕                       보코 리버시블 무스탕
# ...                                ...                               ...
# 1687                     조방할매 낙곱새 6팩세트                       조방할매 낙곱새 세트
# 1688  파격가 니봇 무선 진공 물걸레 로봇청소기 +뉴헤어드라이어기  파격가 니봇 무선 진공 물걸레 로봇청소기  뉴헤어드라이어기
# 1689                        램프쿡 자동회전냄비                        램프쿡 자동회전냄비
# 1690               벨라홈 스마트 멀티포트 1+1 세트                   벨라홈 스마트 멀티포트 세트
# 1691                     코몽트 기모 터틀넥 5종                        코몽트 기모 터틀넥
#
# [1692 rows x 2 columns]

# %% [markdown]
# # 네이버 카테고리 검색기
#
# **혜인**
#
# ID: OpYVfNnlgdKhnWHmxlxa
#
# PW: acYb7du6_E
#
#
# **왕수**
#
# ID: tdrEWZrN1ZQp9u0yqy3e
#
# PW: 59Bl3ltKdX

# %%
# 네이버 검색 API를 이용하여 세부 카테고리를 검색합니다.
def naver_shop(keyword):
    client_id = "DWNxDn7nWmw_X5LC74yj"
    client_secret = "MFrEW9wCWI"
    keyword = keyword.strip()
    encText = urllib.parse.quote(keyword)
    url = "https://openapi.naver.com/v1/search/shop.json?query=" + encText + "&display=1" # json 결과
    # url = "https://openapi.naver.com/v1/search/shop.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        jsonString = response_body.decode('utf-8')
        j = json.loads(jsonString)
        if int(j['total']):
            c1 = j["items"][0]['category1']
            c2 = j["items"][0]["category2"]
            c3 = j["items"][0]["category3"]
            c4 = j["items"][0]["category4"]
            keyword2=''
        else : # 검색결과가 없을경우 모델명(숫자+알파벳 구성)과 사이즈(주로 한자어)를 제거하고 뒤에서부터 2개의 어절만으로 검색 재시도
            p_code = re.compile('[0-9a-zA-Z]+$|[一-龥]+$')
            keyword2 = p_code.sub(' ',keyword)
            keyword2 = keyword2.strip()
            keyword2 = p_code.sub(' ',keyword2)
            keyword2 = ' '.join(keyword2.split()[-2:])
            
            encText = urllib.parse.quote(keyword2)
            url = "https://openapi.naver.com/v1/search/shop.json?query=" + encText + "&display=1"
            request = urllib.request.Request(url)
            request.add_header("X-Naver-Client-Id",client_id)
            request.add_header("X-Naver-Client-Secret",client_secret)
            response = urllib.request.urlopen(request)
            rescode = response.getcode()
            
            if(rescode==200):
                response_body = response.read()
                jsonString = response_body.decode('utf-8')
                j = json.loads(jsonString)
                if int(j['total']):
                    c1 = j["items"][0]['category1']
                    c2 = j["items"][0]["category2"]
                    c3 = j["items"][0]["category3"]
                    c4 = j["items"][0]["category4"]
                else :
                    print(keyword,'->',keyword2)
                    print('>>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<')
                    c1, c2, c3, c4 = '', '', '', ''
            else :
                print("Error Code:" + rescode)
    else:
        print("Error Code:" + rescode)
    return [keyword,c1,c2,c3,c4,keyword2]

# %%
from tqdm import tqdm_notebook

cat_df = pd.DataFrame(columns = ['pname','cat1','cat2','cat3','cat4','pname2'])

for item in tqdm_notebook(ap):
#     print(item)
    ns = naver_shop(item)
    cat_df=cat_df.append(pd.DataFrame([ns],columns=['pname','cat1','cat2','cat3','cat4','pname2']), ignore_index=True)

cat_df
# Out:
# HBox(children=(IntProgress(value=0, max=1266), HTML(value='')))
# USPA화이트라벨 남성모크넥세트 -> USPA화이트라벨 남성모크넥세트
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 창녕 마늘양파듬뿍삼계탕 -> 창녕 마늘양파듬뿍삼계탕
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 스튜디오럭스 후드롱구스다운코트 -> 스튜디오럭스 후드롱구스다운코트
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 메이듀 여성 린넨 블렌디드 슬립온 -> 블렌디드 슬립온
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 루시헨느 레이스 홀리데이 란쥬 -> 홀리데이 란쥬
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 크리스티나앤코 기모밴딩팬츠 -> 크리스티나앤코 기모밴딩팬츠
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 한삼인순홍삼진 -> 한삼인순홍삼진
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 리복 남성 스피드윅 웜웨어 -> 스피드윅 웜웨어
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 에트로 프로푸미 웨이스트백 -> 프로푸미 웨이스트백
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 탕요일 -> 탕요일
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 소들녘 더 맛있는 NEW 돼지왕구이 -> NEW 돼지왕구이
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 리복 여성 스피드윅 웜웨어 -> 스피드윅 웜웨어
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# USPA화이트라벨 여성모크넥세트 -> USPA화이트라벨 여성모크넥세트
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 삼익가구 LED 제니비 침대 -> 제니비 침대
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 자미코코 매트릭스 -> 자미코코 매트릭스
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 우리바다 손질왕꼬막 -> 우리바다 손질왕꼬막
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 한샘 뉴퍼스티지R 리클라이너 -> 뉴퍼스티지R 리클라이너
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 크리스티나앤코 이지웨어세트 -> 크리스티나앤코 이지웨어세트
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 뱅뱅 남성 간절기 데님팬츠  GQE772 GQE774 GQE776 -> 데님팬츠 GQE772
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 마르엘라로사티 에코무스탕 -> 마르엘라로사티 에코무스탕
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 메이듀 남성 린넨 블렌디드 슬립온 -> 블렌디드 슬립온
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 크로커다일 에어스킨 감탄브라 -> 에어스킨 감탄브라
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 레이프릴 더블엑스 매직니퍼팬티 -> 더블엑스 매직니퍼팬티
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 아리스토우 남성기모티셔츠 -> 아리스토우 남성기모티셔츠
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# USPA화이트라벨 남성트랙수트 -> USPA화이트라벨 남성트랙수트
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# PAT 남성 에어 카타티셔츠 -> 에어 카타티셔츠
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 카파 발란스테크 브라팬티 -> 발란스테크 브라팬티
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 바다원  더 그릴 아구채  양태채  쥐포채  소스 -> 쥐포채 소스
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 몬테밀라노 크루즈 이지웨어 -> 크루즈 이지웨어
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 잔다리 전두부세트 -> 잔다리 전두부세트
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 코펜하겐럭스 세미와이드팬츠 -> 코펜하겐럭스 세미와이드팬츠
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 비가린 배추김치 -> 비가린 배추김치
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 아가타 컬러풀에디션 -> 아가타 컬러풀에디션
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# AAE LA갈비 -> AAE LA갈비
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 뽕셰프 이봉원 특갈비탕 -> 이봉원 특갈비탕
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 코펜하겐럭스 판초니트 -> 코펜하겐럭스 판초니트
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 거창특등급사과 -> 거창특등급사과
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 삼성5도어냉장고 T9000 RF84R9203S8   시카고커트러리5p세트 -> RF84R9203S8 시카고커트러리5p세트
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 가이거  제니스시계 주얼리세트 -> 제니스시계 주얼리세트
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# USPA화이트라벨 여성트랙수트 -> USPA화이트라벨 여성트랙수트
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 도냄  쿠쿠전기밥솥 -> 도냄 쿠쿠전기밥솥
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
# 더커진거창특등급사과 -> 더커진거창특등급사과
# >>>>>>>>>>>>>>>>>>>>Search Failed!<<<<<<<<<<<<<<<<<<<<
#                         pname    cat1       cat2     cat3   cat4 pname2
# 0            썸덱스 쉬룰 데일리 백팩 세트    패션잡화       여성가방      숄더백
# 1      안드레아바나 리얼카이만 악어 바디 숄더백    패션잡화       여성가방      숄더백
# 2             시크릿 라메종 볼륨 스프레이  화장품/미용     헤어스타일링   헤어스프레이
# 3             파뷔에 항균 뱀부 식기건조대   생활/건강       주방용품   주방수납용품  식기건조대
# 4                테이트 남성 기모티셔츠    패션의류       남성의류      티셔츠
# ...                       ...     ...        ...      ...    ...    ...
# 1261           리복 델타 피트니스 드로즈    패션의류  남성언더웨어/잠옷       팬티
# 1262           마르엘라로사티 기모본딩팬츠    패션의류       여성의류       바지
# 1263            헤드 파이로라이트 드로즈    패션의류  남성언더웨어/잠옷       팬티
# 1264  로베르타 디 까메리노 올레이스 지퍼브라팬티    패션의류  여성언더웨어/잠옷   브라팬티세트
# 1265                   손질 피꼬막      식품         수산  해산물/어패류     꼬막
#
# [1266 rows x 6 columns]

# %%
len(cat_df)
unknown_ratio = len(cat_df[cat_df['cat1']==''])/len(cat_df)*100
print("알아내지 못한 카테고리 비율 : ", round(unknown_ratio,3),"%")
# Out:
# 알아내지 못한 카테고리 비율 :  3.318 %

# %% [markdown]
# ### 찾지 못한 키워드는
#
#
# 1) 제품코드일 가능성이 높은 알파벳+숫자만으로 이루어진 덩어리 제거
#
# 2) 제품 명사일 가능성이 높은 맨 뒷 2어절 탐색 >>>>>>>>>>>>>>>>>>>>> 검색기 내부에서 작동
#
#
#
#
# **그래도 못찾으면?**
#
#
# 1) 유사도 기준 참조

# %% [markdown]
# # 유사도 탐색기
#
# ## HOW? : Jaccard_Similarity
#
# > 문장을 명사단위로 쪼갠 뒤 두 문장간 (겹치는 명사의 개수) / (총 명사의 수) 로 구하는 유사도
#
# >> 예시) Jaccard('특대형 한방닭백숙', '김개똥의 닭백숙 세트') --> ('특','특대형','한방','닭','닭백숙','백숙'), ('김개똥','닭','닭백숙','백숙','세트)
#
# >> A&B = 6개(3쌍) ('닭','백숙','닭백숙')
#
# >> A|B = 11개
#
# >> Jaccard_sim = 6/11 = 54.5%

# %%
from tqdm import tqdm_notebook
from konlpy.tag import Kkma
kkma=Kkma()
def jaccard_sim(doc1, doc2):
    doc1 = kkma.nouns(doc1)
    doc2 = kkma.nouns(doc2)
    u_doc1 = set(doc1)
    u_doc2 = set(doc2)
    return len(u_doc1 & u_doc2) / len(u_doc1 | u_doc2)

# %%
cat_df.to_csv('fisrt_search_cat.csv')

# %%
# cat_df = pd.read_csv('좀더_전처리_카테고리결과.csv',index_col=0)
unknown = cat_df[cat_df['cat1']=='']
known = cat_df[cat_df['cat1']!='']
for i in tqdm_notebook(range(len(unknown))):
    best_sim = 0
    print(unknown.iloc[i].pname)
    for j in tqdm_notebook(range(len(known))):
        sim = jaccard_sim(unknown.iloc[i].pname,known.iloc[j].pname)
        if sim > best_sim :
            best_sim = sim
            best_ind = j
            print(best_sim)
    unknown.iloc[i].cat1 = known.iloc[best_ind].cat1
    unknown.iloc[i].cat2 = known.iloc[best_ind].cat2
    unknown.iloc[i].cat3 = known.iloc[best_ind].cat3
    unknown.iloc[i].cat4 = known.iloc[best_ind].cat4
    print(known.iloc[best_ind].cat1, known.iloc[best_ind].cat2,known.iloc[best_ind].cat3,known.iloc[best_ind].cat4)
# Out:
# HBox(children=(IntProgress(value=0, max=42), HTML(value='')))
# USPA화이트라벨 남성모크넥세트
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.0625
# 0.08333333333333333
# 0.1
# 0.36363636363636365
# 0.4
#
# 패션의류 남성의류 티셔츠
# 창녕 마늘양파듬뿍삼계탕
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.1
#
# 식품 축산 축산가공식품 삼계탕
# 스튜디오럭스 후드롱구스다운코트
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.25
#
# 패션의류 여성의류 점퍼
# 메이듀 여성 린넨 블렌디드 슬립온
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.1
# 0.1111111111111111
# 0.2222222222222222
# 0.2727272727272727
#
# 패션의류 여성의류 블라우스/셔츠
# 루시헨느 레이스 홀리데이 란쥬
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.058823529411764705
# 0.0625
# 0.07142857142857142
# 0.08333333333333333
# 0.11764705882352941
#
# 패션의류 여성언더웨어/잠옷 브라팬티세트
# 크리스티나앤코 기모밴딩팬츠
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.07692307692307693
# 0.13333333333333333
# 0.14285714285714285
# 0.16666666666666666
# 0.2
# 0.38461538461538464
# 0.4166666666666667
# 0.5
# 0.6363636363636364
#
# 패션의류 여성의류 바지
# 한삼인순홍삼진
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 패션의류 여성의류 바지
# 리복 남성 스피드윅 웜웨어
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.07142857142857142
# 0.08333333333333333
# 0.09090909090909091
# 0.14285714285714285
# 0.2
# 0.5454545454545454
#
# 패션의류 남성언더웨어/잠옷 팬티
# 에트로 프로푸미 웨이스트백
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.06666666666666667
# 0.09090909090909091
# 0.18181818181818182
# 0.5555555555555556
#
# 패션잡화 여성가방 크로스백
# 탕요일
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.14285714285714285
#
# 식품 냉동/간편조리식품 즉석국/즉석탕
# 소들녘 더 맛있는 NEW 돼지왕구이
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.1
# 0.125
# 0.375
#
# 식품 냉동/간편조리식품 즉석국/즉석탕
# 리복 여성 스피드윅 웜웨어
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.07692307692307693
# 0.08333333333333333
# 0.09090909090909091
# 0.13333333333333333
# 0.15384615384615385
# 0.2
# 0.5454545454545454
#
# 패션의류 남성언더웨어/잠옷 팬티
# USPA화이트라벨 여성모크넥세트
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.0625
# 0.09090909090909091
# 0.25
# 0.4
#
# 패션의류 여성의류 티셔츠
# 삼익가구 LED 제니비 침대
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.06666666666666667
# 0.1
# 0.6666666666666666
#
# 가구/인테리어 침실가구 침대 침대프레임
# 자미코코 매트릭스
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.1
# 0.1111111111111111
# 0.23076923076923078
# 0.8
#
# 가구/인테리어 침실가구 매트리스 더블매트리스
# 우리바다 손질왕꼬막
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.09090909090909091
# 0.14285714285714285
# 0.16666666666666666
# 0.2
# 0.5555555555555556
#
# 식품 수산 해산물/어패류 전복
# 한샘 뉴퍼스티지R 리클라이너
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.05555555555555555
# 0.06666666666666667
# 0.07692307692307693
# 0.25
# 0.5
#
# 가구/인테리어 거실가구 소파 리클라이너소파
# 크리스티나앤코 이지웨어세트
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.058823529411764705
# 0.07142857142857142
# 0.08333333333333333
# 0.1
# 0.26666666666666666
# 0.5
# 0.5454545454545454
#
# 패션의류 여성의류 코디세트
# 뱅뱅 남성 간절기 데님팬츠  GQE772 GQE774 GQE776
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.07142857142857142
# 0.125
# 0.18181818181818182
# 0.36363636363636365
# 0.42857142857142855
#
# 패션의류 남성의류 청바지
# 마르엘라로사티 에코무스탕
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.07142857142857142
# 0.07692307692307693
# 0.5
# 0.5555555555555556
#
# 패션의류 여성의류 청바지
# 메이듀 남성 린넨 블렌디드 슬립온
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.09090909090909091
# 0.1111111111111111
# 0.125
# 0.2
# 0.2222222222222222
# 0.2727272727272727
#
# 패션의류 여성의류 블라우스/셔츠
# 크로커다일 에어스킨 감탄브라
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.07142857142857142
# 0.21428571428571427
# 0.3
#
# 패션의류 여성언더웨어/잠옷 브라팬티세트
# 레이프릴 더블엑스 매직니퍼팬티
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.0625
# 0.25
# 0.26666666666666666
#
# 패션의류 여성언더웨어/잠옷 보정속옷 거들
# 아리스토우 남성기모티셔츠
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.3333333333333333
# 0.5714285714285714
#
# 패션의류 남성의류 티셔츠
# USPA화이트라벨 남성트랙수트
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.09090909090909091
# 0.1111111111111111
# 0.4
# 0.4444444444444444
#
# 패션의류 남성의류 티셔츠
# PAT 남성 에어 카타티셔츠
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.2857142857142857
# 0.4
# 0.5
# 0.75
#
# 스포츠/레저 골프 골프의류 티셔츠
# 카파 발란스테크 브라팬티
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.058823529411764705
# 0.23076923076923078
# 0.2727272727272727
# 0.3333333333333333
# 0.375
#
# 패션의류 여성언더웨어/잠옷 브라팬티세트
# 바다원  더 그릴 아구채  양태채  쥐포채  소스
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.045454545454545456
# 0.058823529411764705
#
# 식품 수산 생선 장어
# 몬테밀라노 크루즈 이지웨어
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.2
# 0.21428571428571427
# 0.23076923076923078
#
# 패션의류 여성의류 레깅스
# 잔다리 전두부세트
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.06666666666666667
# 0.07142857142857142
# 0.1
# 0.125
#
# 패션의류 남성의류 트레이닝복
# 코펜하겐럭스 세미와이드팬츠
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.0625
# 0.07692307692307693
# 0.08333333333333333
# 0.14285714285714285
# 0.15384615384615385
# 0.5
#
# 패션의류 여성의류 바지
# 비가린 배추김치
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.07142857142857142
# 0.1111111111111111
# 0.14285714285714285
#
# 식품 김치 포기김치
# 아가타 컬러풀에디션
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.07692307692307693
# 0.08333333333333333
# 0.3333333333333333
# 0.5
#
# 출산/육아 교재/서적 유아동전집 기타전집
# AAE LA갈비
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.125
# 0.16666666666666666
#
# 식품 축산 축산가공식품 쇠고기양념육
# 뽕셰프 이봉원 특갈비탕
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.07692307692307693
# 0.1
#
# 식품 냉동/간편조리식품 즉석국/즉석탕
# 코펜하겐럭스 판초니트
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.07142857142857142
# 0.07692307692307693
# 0.16666666666666666
# 0.4166666666666667
#
# 패션의류 여성의류 바지
# 거창특등급사과
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.2
#
# 식품 농산물 과일 포도
# 삼성5도어냉장고 T9000 RF84R9203S8   시카고커트러리5p세트
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.047619047619047616
# 0.0625
# 0.07142857142857142
# 0.09523809523809523
# 0.1111111111111111
# 0.2777777777777778
# 0.5
#
# 디지털/가전 주방가전 냉장고 양문형냉장고
# 가이거  제니스시계 주얼리세트
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.0625
# 0.09090909090909091
# 0.1111111111111111
# 0.3076923076923077
#
# 패션잡화 주얼리 주얼리세트 14K세트
# USPA화이트라벨 여성트랙수트
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.1
# 0.2727272727272727
# 0.3333333333333333
# 0.4444444444444444
#
# 패션의류 여성의류 티셔츠
# 도냄  쿠쿠전기밥솥
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.09090909090909091
# 0.1
# 0.4444444444444444
# 0.8333333333333334
#
# 디지털/가전 주방가전 전기밥솥 압력밥솥
# 더커진거창특등급사과
# HBox(children=(IntProgress(value=0, max=1224), HTML(value='')))
# 0.18181818181818182
#
# 식품 농산물 과일 포도

# %%
full_cat_df.to_csv('temp.csv',index='ignore')

# %%
tmp = pd.merge(p_name,pd.concat([known,unknown]),left_on = 'After Process', right_on = 'pname').drop(['pname','pname2','After Process'],axis=1)
re_performance = pd.merge(performance,tmp,left_on='상품명',right_on='Before Process').drop(['Before Process'],axis=1)
re_performance.to_csv('categorized_performance.csv')
